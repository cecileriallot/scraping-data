# %% [markdown]
# # LIST OF CUSTOM OFFICES AT THE FRENCH POINTS OF ENTRY INTO THE EUROPEAN UNION (AIRPORTS)
#
# ## *Scraping/Parsing/Cleaning/Reshaping/Translating data from a PDF*
#
# The data will be extracted from a PDF containing [a list of the French points of entry into the European Union and their respective custom offices.](https://www.douane.gouv.fr/sites/default/files/uploads/files/Services-en-ligne/ICS/ics-liste-points-d-entree-francais.pdf)
#
# As stated by the French Customs:
#
# >* **"The names of the airports which constitute the first points of entry, or subsequent points, are included here, as well as the codes of the customs offices which are attached to them."**
# * **"All the air entry points open to international traffic, on which flights from third countries are likely to land, are also listed."**
#
# The data related to airports in the file `ics-liste-points-d-entree-francais.pdf` starts on page 3, ends on page 7, and the table on each page has headers.
#
# The data will be extracted using the [`pdfplumber`](https://github.com/jsvine/pdfplumber) tool.
#
# #### Steps:
# 1. Import dependencies
# 2. Open the PDF and check its structure
# 3. Create an empty data frame and specify the columns
# 4. Create a function to extract data from a single PDF page and return a data frame
# 5. Loop over the pages and call the function on each page
# 6. Clean up and translate the data
# 7. Perform a quick basic analysis in pandas
# 8. Write the data to a CSV file

# %% [markdown]
# ### 1. Import dependencies

# %%
import pdfplumber
import pandas as pd

# %%
# Set pandas display options (optional)
pd.set_option("display.max_columns", None)
pd.set_option("display.max_rows", None)
pd.set_option("display.max_colwidth", -1)

# %% [markdown]
# ### 2. Open the PDF and check its structure
#
# Using `pdfplumber`'s syntax to open a file, explore the PDF structure and extract the airports data table located on page 3.

# %%
with pdfplumber.open("ics-liste-points-d-entree-francais.pdf") as pdf:
    
    # print(pdf)
    # print(pdf.pages)
    test = pdf.pages[3]
    table = test.extract_table()
    print(table)
# Out:
# [["Nom du Point d'entrée", 'Nom \ndu bureau', 'Code\nBureau', 'Trafic', 'Code \nIATA', 'Code \nOACI'], ['►Aéroports ayant un trafic de fret pays tiers', None, None, None, None, None], ['Agen La Garenne', 'Agen', 'FR005130', 'Aéroport (AIR)', 'AGF', 'LFBA'], ['Bâle Mulhouse', 'Bâle Mulhouse aéroport', 'FR000340', 'Aéroport (AIR)', 'BSL\nMLH', 'LFBD'], ['Bordeaux Mérignac', 'Bordeaux Mérignac', 'FR000600', 'Aéroport (AIR)', 'BOD', 'LFBD'], ['Brest Guipavas', 'Brest', 'FR000690', 'Aéroport (AIR)', 'BES', 'LFRB'], ['Châteauroux Déols', 'Châteauroux', 'FR000910', 'Aéroport (AIR)', 'CHR', 'LFLX'], ['Deauville Saint-Gatien', 'Caen', 'FR000720', 'Aéroport (AIR)', 'DOL', 'LFRG'], ['Dinard Pleurtuit', 'Saint-Malo', 'FR004060', 'Aéroport (AIR)', 'DNR', 'LFRD'], ['Évreux', 'Rouen port', 'FR003920', 'Aéroport (AIR)', 'DPE', 'LFAB'], ['Lille Lesquin', 'Lesquin', 'FR005350', 'Aéroport (AIR)', 'LIL', 'LFQQ'], ['Lyon Saint-Exupéry', 'Lyon aéroport', 'FR002650', 'Aéroport (AIR)', 'LYS', 'LFLL'], ['Marseille Marignane', 'Marignane aéroport', 'FR002710', 'Aéroport (AIR)', 'MRS', 'LFML'], ['Metz Nancy-Lorraine', 'Ennery', 'FR001280', 'Aéroport (AIR)', 'ETZ', 'LFJL']]

# %% [markdown]
# ### 3. Create an empty data frame and define the columns

# %%
cols = ["point_of_entry_name", "office_name", "office_code", "traffic", "iata_code", "icao_code"]

df = pd.DataFrame(columns=cols)

# %% [markdown]
# ### 4. Create a function to extract data from a single PDF page
#
# This function will be called on every PDF page we hand it. It will take a `pdfplumber.Page` object, extract the table and return the data in a data frame with the same headers as the empty one we just created.

# %%
def page_to_df(page):
    
    # Find the table on the page and extract the data
    table = page.extract_table()
    
    # Grab all rows in the table except for the first one,
    # which is the header row
    lines = table[1:]
    
    # Return the data in a dataframe
    return pd.DataFrame(lines, columns=cols)

# %% [markdown]
# ### 5. Loop over the pages and call the function on each page
#
# As we extract the data from each page, we'll append the data frame returned by our function to the empty data frame (`df`) that we created earlier.

# %%
# Open the PDF
with pdfplumber.open("ics-liste-points-d-entree-francais.pdf") as pdf:
    
    # Skip the first 3 pages that do not contain the data table we need
    pages_with_data = pdf.pages[3:]
    
    # Loop over the pages with data
    for page in pages_with_data:
        
        # Call the extraction function to grab the data from this page
        df_to_append = page_to_df(page)
        
        # Append it to our main data frame, chopping off the index column
        df = df.append(df_to_append, ignore_index=True)

# %%
df
# Out:
#                                         point_of_entry_name  \
# 0    ►Aéroports ayant un trafic de fret pays tiers
# 1    Agen La Garenne
# 2    Bâle Mulhouse
# 3    Bordeaux Mérignac
# 4    Brest Guipavas
# 5    Châteauroux Déols
# 6    Deauville Saint-Gatien
# 7    Dinard Pleurtuit
# 8    Évreux
# 9    Lille Lesquin
# 10   Lyon Saint-Exupéry
# 11   Marseille Marignane
# 12   Metz Nancy-Lorraine
# 13   ►Aéroports ayant un trafic de fret pays tiers
# 14   Montpellier Méditerranée
# 15   Morlaix Ploujean
# 16   Nantes Atlantique
# 17   Nice
# 18   Orly
# 19   Roissy
# 20   Saint-Brieuc Armor
# 21   Strasbourg Entzheim
# 22   Toulouse Blagnac
# 23   Vatry
# 24   DOM
# 25   Guadeloupe pôle Caraïbes \n(Pointe à pitre Le Raizet)
# 26   Martinique Aimé Césaire \n(Fort-de-France Le Lamentin)
# 27   Saint-Denis Gillot \n(La Réunion)
# 28   Saint-Pierre Pierrefonds \n(La Réunion)
# 29   Dzaoudzi Pamandzi (Mayotte)
# 30   ►Aéroports habilités à recevoir du fret pays tiers
# 31   Abbeville Buigny-Saint-Maclou
# 32   Ajaccio Campo dell'Oro
# 33   Albert Bray
# 34   Albi Le Séquestre
# 35   Amiens Glisy
# 36   Angers Loire
# 37   Angoulême Brie-Champniers
# 38   Annecy Haute-Savoie
# 39   Annemasse
# 40   Auxerre Branches
# 41   Avignon
# 42   Bastia Poretta
# 43   Biarritz Anglet Bayonne
# 44   Beauvais Tillé
# 45   Bergerac Roumanières \n(Bergerac Dordogne)
# 46   ► Aéroports habilités à recevoir du fret pays tiers
# 47   Besançon La Vèze
# 48   Béziers Agde Vias
# 49   Blois Le Breuil
# 50   Bourges
# 51   Brive Souillac\n(Vallée de la Dordogne)
# 52   Caen Carpiquet
# 53   Cahors Lalbenque
# 54   Calais Dunkerque
# 55   Calvi Sainte-Catherine
# 56   Cannes Mandelieu
# 57   Carcassonne Salveza\n(Pays Cathare)
# 58   Castres Mazamet
# 59   Chalon Champforgeuil
# 60   Chambéry Aix-les-Bains
# 61   Charleville Mézières
# 62   Cherbourg Maupertuis
# 63   Clermont-Ferrand Aulnat
# 64   Colmar Houssen
# 65   Courchevel
# 66   Dieppe Saint-Aubin
# 67   Dijon Lonvic \n(Dijon Bourgogne)
# 68   Dôle Tavaux
# 69   Épinal Mirecourt
# 70   Figari Sud Corse
# 71   Gap Tallard
# 72   Granville
# 73   Gray
# 74   Grenoble Saint-Geoirs
# 75   Hyères Le Palivestre\n(Toulon Hyères)
# 76   Issy-les-Moulineaux
# 77   Lannion
# 78   Laval Entrammes
# 79   Limoges Bellegarde
# 80   Lognes Emerainville
# 81   ►Aéroports habilités à recevoir du fret pays tiers
# 82   Lorient Lann-Bihoué
# 83   Lyon Bron
# 84   La Môle Saint-Tropez
# 85   La Rochelle Laleu \n(La Rochelle Île de Ré)
# 86   Le Bourget
# 87   Le Castellet
# 88   Le Havre Octeville
# 89   Le Mans Arnage
# 90   Le Touquet Paris-plage\n(Côte d'Opale)
# 91   Meaux Esbly
# 92   Megève
# 93   Montbéliard Courcelles
# 94   Nancy Essey
# 95   Nevers Fourchambault
# 96   Nîmes Garons
# 97   Orléans Bricy
# 98   Orléans Saint-Denis-de-L'Hôtel
# 99   Pau Pyrénées
# 100  Périgueux Bassillac
# 101  Perpignan Rivesaltes
# 102  Poitiers Biard
# 103  Pontarlier
# 104  Pontoise Cormeilles-en-Vexin
# 105  Quimper Pluguffan\n(Quimper Cornouailles)
# 106  Reims Champagne
# 107  Rennes Saint-Jacques
# 108  Roanne Renaison
# 109  Rodez Marcillac
# 110  Rouen Vallée de Seine
# 111  Saint-Étienne Bouthéon
# 112  Saint-Nazaire Montoir
# 113  Saint Yan
# 114  Tarbes Lourdes Pyrénées
# 115  Tours Val de Loire
# 116  ► Aéroports habilités à recevoir du fret pays tiers
# 117  Troyes Barberey
# 118  Valence Chabeuil
# 119  Valenciennes Denain
# 120  Vannes Meucon \n(Vannes Golfe du Morbihan)
# 121  Vesoul Frotey
# 122  Vichy Charmeilles
#
#                    office_name office_code         traffic iata_code icao_code
# 0    None                       None        None            None      None
# 1    Agen                       FR005130    Aéroport (AIR)  AGF       LFBA
# 2    Bâle Mulhouse aéroport     FR000340    Aéroport (AIR)  BSL\nMLH  LFBD
# 3    Bordeaux Mérignac          FR000600    Aéroport (AIR)  BOD       LFBD
# 4    Brest                      FR000690    Aéroport (AIR)  BES       LFRB
# 5    Châteauroux                FR000910    Aéroport (AIR)  CHR       LFLX
# 6    Caen                       FR000720    Aéroport (AIR)  DOL       LFRG
# 7    Saint-Malo                 FR004060    Aéroport (AIR)  DNR       LFRD
# 8    Rouen port                 FR003920    Aéroport (AIR)  DPE       LFAB
# 9    Lesquin                    FR005350    Aéroport (AIR)  LIL       LFQQ
# 10   Lyon aéroport              FR002650    Aéroport (AIR)  LYS       LFLL
# 11   Marignane aéroport         FR002710    Aéroport (AIR)  MRS       LFML
# 12   Ennery                     FR001280    Aéroport (AIR)  ETZ       LFJL
# 13   None                       None        None            None      None
# 14   Montpellier Méditerranée   FR006710    Aéroport (AIR)  MPL       LFMT
# 15   Brest                      FR000690    Aéroport (AIR)  MXN       LFRU
# 16   Nantes Atlantique          FR003030    Aéroport (AIR)  NTE       LFRS
# 17   Nice aéroport              FR003080    Aéroport (AIR)  NCE       LFMN
# 18   Orly                       FR003370    Aéroport (AIR)  ORY       LFPO
# 19   Roissy prise en charge     FR00677A    Aéroport (AIR)  CDG       LFPG
# 20   Saint-Brieuc               FR002310    Aéroport (AIR)  SBK       LFRT
# 21   Strasbourg Entzheim        FR004310    Aéroport (AIR)  SXB       LFST
# 22   Toulouse Blagnac aéroport  FR004440    Aéroport (AIR)  TLS       LFBO
# 23   Reims                      FR003790    Aéroport (AIR)  XCR       LFOK
# 24   None                       None        None            None      None
# 25   Le Raizet aéroport         FR006330    Aéroport (AIR)  PTP       TFFR
# 26   Le Lamentin aéroport       FR006440    Aéroport (AIR)  FDF       TFFF
# 27   Saint-Denis aéroport       FR006460    Aéroport (AIR)  RUN       FMEE
# 28   Saint-Pierre               FR006430    Aéroport (AIR)  ZSE       FMEP
# 29   Pamandzi                   FR006810    Aéroport (AIR)  DZA       FMCZ
# 30   None                       None        None            None      None
# 31   Amiens                     FR000100    Aéroport (AIR)            LFOI
# 32   Ajaccio port               FR000040    Aéroport (AIR)  AJA       LFKJ
# 33   Amiens                     FR000100    Aéroport (AIR)
# 34   Albi                       FR005800    Aéroport (AIR)  LBI       LFCI
# 35   Amiens                     FR000100    Aéroport (AIR)            LFAY
# 36   Angers                     FR000120    Aéroport (AIR)  ANE       LFJR
# 37   Angoulême                  FR000130    Aéroport (AIR)  ANG       LFBU
# 38   Annecy                     FR000140    Aéroport (AIR)  NCY       LFLP
# 39   Vallard-Thonex             FR006670    Aéroport (AIR)            LFLI
# 40   Auxerre                    FR005500    Aéroport (AIR)  AUF       LFLA
# 41   Avignon                    FR000270    Aéroport (AIR)  AVN       LFMV
# 42   Bastia port                FR000380    Aéroport (AIR)  BIA       LFKB
# 43   Bayonne                    FR000390    Aéroport (AIR)  BIQ       LFBZ
# 44   Compiègne                  FR004990    Aéroport (AIR)  BVA       LFOB
# 45   Bassens                    FR000610    Aéroport (AIR)
# 46   None                       None        None            None      None
# 47   Besançon                   FR000460    Aéroport (AIR)            LFQM
# 48   Sète                       FR004250    Aéroport (AIR)  BZR       LFMU
# 49   Blois                      FR000530    Aéroport (AIR)            LFOQ
# 50   Bourges                    FR000640    Aéroport (AIR)  BOU       LFLD
# 51   Brive                      FR004960    Aéroport (AIR)  BVE       LFBV
# 52   Caen                       FR000720    Aéroport (AIR)  CFR       LFRK
# 53   Cahors                     FR005470    Aéroport (AIR)  ZAO       LFCC
# 54   Boulogne                   FR000630    Aéroport (AIR)  CQF       LFAC
# 55   Bastia port                FR000380    Aéroport (AIR)  CLY       LFKC
# 56   Nice aéroport              FR003080    Aéroport (AIR)  CEQ       LFMD
# 57   Port-la-Nouvelle           FR003650    Aéroport (AIR)  CCF       LFMK
# 58   Albi                       FR005800    Aéroport (AIR)  DCM       LFCK
# 59   Chalon-sur-Saône           FR000860    Aéroport (AIR)            LFLH
# 60   Chambéry                   FR000870    Aéroport (AIR)  CMF       LFLB
# 61   Charleville                FR000900    Aéroport (AIR)            LFQV
# 62   Caen                       FR000720    Aéroport (AIR)  CER       LFRC
# 63   Clermont-Ferrrand          FR000980    Aéroport (AIR)  CFE       LFLC
# 64   Mulhouse                   FR002990    Aéroport (AIR)  CMR       LFGA
# 65   Chambéry                   FR000870    Aéroport (AIR)  CVF       LFLJ
# 66   Rouen port                 FR003920    Aéroport (AIR)  DPE       LFAB
# 67   Dijon                      FR001170    Aéroport (AIR)  DIJ       LFGI
# 68   Lons-le-Saulnier           FR005260    Aéroport (AIR)  DLE       LFGJ
# 69   Épinal                     FR001290    Aéroport (AIR)  EPL       LFSG
# 70   Ajaccio port               FR000040    Aéroport (AIR)  FSC       LFKF
# 71   Gap                        FR005830    Aéroport (AIR)  GAT       LFNA
# 72   Caen                       FR000720    Aéroport (AIR)  GFR       LFRF
# 73   Besançon                   FR000460    Aéroport (AIR)            LFEV
# 74   Grenoble                   FR001610    Aéroport (AIR)  GNB       LFLS
# 75   Toulon                     FR004430    Aéroport (AIR)  JLN       LFTH
# 76   Gennevilliers              FR003410    Aéroport (AIR)  JDP       LFPI
# 77   Saint-Brieuc               FR002310    Aéroport (AIR)  LAI       LFRO
# 78   Angers                     FR000120    Aéroport (AIR)  LVA       LFOV
# 79   Limoges                    FR002540    Aéroport (AIR)  LIG       LFBL
# 80   Marne-la-Vallée            FR006270    Aéroport (AIR)            LFPL
# 81   None                       None        None            None      None
# 82   Lorient                    FR002600    Aéroport (AIR)  LRT       LFRH
# 83   Lyon aéroport              FR002650    Aéroport (AIR)  LYN       LFLY
# 84   Toulon                     FR004430    Aéroport (AIR)            LFTZ
# 85   La Rochelle Pallice        FR002090    Aéroport (AIR)  LRH       LFBH
# 86   Roissy prise en charge     FR00677A    Aéroport (AIR)  LBG       LFPB
# 87   Toulon                     FR004430    Aéroport (AIR)  CTT       LFMQ
# 88   Le Havre port              FR002300    Aéroport (AIR)  LEH       LFOH
# 89   Le Mans                    FR002340    Aéroport (AIR)  LME       LFRM
# 90   Boulogne                   FR000630    Aéroport (AIR)  LTQ       LFAT
# 91   Marne-la-Vallée            FR006270    Aéroport (AIR)            LFPE
# 92   Annecy                     FR000140    Aéroport (AIR)  MVV       LFHM
# 93   Delle                      FR001140    Aéroport (AIR)            LFSM
# 94   Nancy                      FR003000    Aéroport (AIR)  ENC       LFSN
# 95   Auxerre                    FR005500    Aéroport (AIR)  NVS       LFQG
# 96   Nîmes                      FR003120    Aéroport (AIR)  FNI       LFTW
# 97   Orléans                    FR003160    Aéroport (AIR)  ORE       LFOJ
# 98   Orléans                    FR003160    Aéroport (AIR)            LFOZ
# 99   Pau                        FR003440    Aéroport (AIR)  PUF       LFBP
# 100  Périgueux                  FR004910    Aéroport (AIR)  PGX       LFBX
# 101  Perpignan                  FR003480    Aéroport (AIR)  PGF       LFMP
# 102  Poitiers                   FR003540    Aéroport (AIR)  PIS       LFBI
# 103  Pontarlier                 FR003550    Aéroport (AIR)            LFSP
# 104  Gennevilliers              FR003410    Aéroport (AIR)  JDP       LFPI
# 105  Brest                      FR000690    Aéroport (AIR)  UIP       LFRQ
# 106  Reims                      FR003790    Aéroport (AIR)  RHE       LFSR
# 107  Rennes                     FR003800    Aéroport (AIR)  RNS       LFRN
# 108  Saint-Étienne aéroport     FR003970    Aéroport (AIR)  RNE       LFLO
# 109  Toulouse Blagnac aéroport  FR004440    Aéroport (AIR)  TLS       LFBO
# 110  Rouen port                 FR003920    Aéroport (AIR)  URO       LFOP
# 111  Saint Étienne aéroport     FR003970    Aéroport (AIR)  EBU       LFMH
# 112  Saint-Nazaire Montoir      FR004080    Aéroport (AIR)  SNR       LFRZ
# 113  Chalon-sur-Saône           FR000860    Aéroport (AIR)  SYT       LFLN
# 114  Tarbes                     FR004350    Aéroport (AIR)  LDE       LFBT
# 115  Tours                      FR004490    Aéroport (AIR)  TUF       LFOT
# 116  None                       None        None            None      None
# 117  Troyes                     FR004520    Aéroport (AIR)            LFQB
# 118  Valence                    FR004550    Aéroport (AIR)  VAF       LFLU
# 119  Valenciennes               FR004560    Aéroport (AIR)            LFAV
# 120  Lorient                    FR002600    Aéroport (AIR)  VNE       LFRV
# 121  Besançon                   FR000460    Aéroport (AIR)            LFQW
# 122  Moulins                    FR005750    Aéroport (AIR)  VHY       LFLV

# %% [markdown]
# ### 6. Clean up the data

# %%
# Kill line breaks
df.replace("\n", " ", inplace=True, regex=True)

# %%
# Make all values uppercase and strip whitespace in all columns
df["point_of_entry_name"] = df.point_of_entry_name.str.upper().str.strip()
df["office_name"] = df.office_name.str.upper().str.strip()
df["office_code"] = df.office_code.str.strip()
df["traffic"] = df.traffic.str.upper().str.strip()
df["iata_code"] = df.iata_code.str.strip()
df["icao_code"] = df.icao_code.str.strip()

# %%
# Remove all French accents from strings in columns "point_of_entry_name", "office_name" and "traffic"
df["point_of_entry_name"] = df.point_of_entry_name.str.normalize("NFKD") \
                                                  .str.encode("ascii", errors="ignore").str.decode("utf-8")
df["office_name"] = df.office_name.str.normalize("NFKD").str.encode("ascii", errors="ignore").str.decode("utf-8")
df["traffic"] = df.traffic.str.normalize("NFKD").str.encode("ascii", errors="ignore").str.decode("utf-8")

# %%
# Select indexes where vector values is equal to "Aéroports ayant un trafic de fret pays tiers"
# Assign "Aéroport ayant un trafic de fret pays tiers" to new column "airport_type"
df.loc[0:30, "airport_type"] = "AIRPORT WITH THIRD COUNTRY FREIGHT TRAFFIC"

# %%
# Select indexes where vector values is equal to "Aéroports habilités à recevoir du fret pays tiers"
# Assign "Aéroport habilités à recevoir du fret pays tiers" value to column "airport_type"
df.loc[30:123, "airport_type"] = "AIRPORT AUTHORIZED TO RECEIVE THIRD COUNTRY FREIGHT"

# %%
# Select indexes where territory values is equal to "Metropole"
# Assign entries to new column "territory"
df.loc[0:24, "territory"] = "MAINLAND"
df.loc[30:123, "territory"] = "MAINLAND"

# %%
# Select indexes where territory values is equal to "DOM"
# Assign entries to column "territory"
df.loc[24:29, "territory"] = "OVERSEAS"

# %%
# Remove all indexes containing vector headers
# Reset index
df = df.drop([0, 13, 30, 46, 81, 116], axis=0).reset_index(drop=True)

# %%
# Remove the index containing a territory header
# Reset index
df = df.drop([22], axis=0).reset_index(drop=True)

# %%
# Replace unique value "AEROPORT (AIR)" in column "traffic" with its English translation
df["traffic"] = "AIRPORT (AIR)"

# %% [markdown]
# ### 7. Perform a quick basic analysis in pandas
#
# Make a quick analysis and write _an entire journalism sentence_ reporting the number of airports with third country freight traffic located in Mainland France that are first points of entry into the European Union as well as the percentage of the total number of airports in the data frame it represents.

# %%
# What is the total number of airports (how many records are there?)
record_count = len(df)

# Filter for only airports with third country freight traffic in Mainland France
airports = df[(df.airport_type == "AIRPORT WITH THIRD COUNTRY FREIGHT TRAFFIC") & (df.territory == "MAINLAND")]

# How many of those are there?
airports_count = len(airports)

# Calculate the percentage of the whole
pct_whole = (airports_count / record_count) * 100

# %% [markdown]
# Formulate a journalistic sentence.

# %%
# Write out a formatted sentence using an f-string
story_sentence = f'Of the {record_count:,} French airports which constitute the first points of entry into the European Union, {airports_count:,} ({pct_whole:0.2f}%) are airports with third country freight traffic that are located in Mainland France.'

print(story_sentence)
# Out:
# Of the 116 French airports which constitute the first points of entry into the European Union, 22 (18.97%) are airports with third country freight traffic that are located in Mainland France.

# %% [markdown]
# ### 8. Write the data to a CSV file

# %%
df.to_csv("list-of-french-points-of-entry-in-eu-airports.csv", sep=",", encoding="utf-8", index=False)

# %%
data = pd.read_csv("list-of-french-points-of-entry-in-eu-airports.csv")

data
# Out:
#                                        point_of_entry_name  \
# 0    AGEN LA GARENNE
# 1    BALE MULHOUSE
# 2    BORDEAUX MERIGNAC
# 3    BREST GUIPAVAS
# 4    CHATEAUROUX DEOLS
# 5    DEAUVILLE SAINT-GATIEN
# 6    DINARD PLEURTUIT
# 7    EVREUX
# 8    LILLE LESQUIN
# 9    LYON SAINT-EXUPERY
# 10   MARSEILLE MARIGNANE
# 11   METZ NANCY-LORRAINE
# 12   MONTPELLIER MEDITERRANEE
# 13   MORLAIX PLOUJEAN
# 14   NANTES ATLANTIQUE
# 15   NICE
# 16   ORLY
# 17   ROISSY
# 18   SAINT-BRIEUC ARMOR
# 19   STRASBOURG ENTZHEIM
# 20   TOULOUSE BLAGNAC
# 21   VATRY
# 22   GUADELOUPE POLE CARAIBES  (POINTE A PITRE LE RAIZET)
# 23   MARTINIQUE AIME CESAIRE  (FORT-DE-FRANCE LE LAMENTIN)
# 24   SAINT-DENIS GILLOT  (LA REUNION)
# 25   SAINT-PIERRE PIERREFONDS  (LA REUNION)
# 26   DZAOUDZI PAMANDZI (MAYOTTE)
# 27   ABBEVILLE BUIGNY-SAINT-MACLOU
# 28   AJACCIO CAMPO DELL'ORO
# 29   ALBERT BRAY
# 30   ALBI LE SEQUESTRE
# 31   AMIENS GLISY
# 32   ANGERS LOIRE
# 33   ANGOULEME BRIE-CHAMPNIERS
# 34   ANNECY HAUTE-SAVOIE
# 35   ANNEMASSE
# 36   AUXERRE BRANCHES
# 37   AVIGNON
# 38   BASTIA PORETTA
# 39   BIARRITZ ANGLET BAYONNE
# 40   BEAUVAIS TILLE
# 41   BERGERAC ROUMANIERES  (BERGERAC DORDOGNE)
# 42   BESANCON LA VEZE
# 43   BEZIERS AGDE VIAS
# 44   BLOIS LE BREUIL
# 45   BOURGES
# 46   BRIVE SOUILLAC (VALLEE DE LA DORDOGNE)
# 47   CAEN CARPIQUET
# 48   CAHORS LALBENQUE
# 49   CALAIS DUNKERQUE
# 50   CALVI SAINTE-CATHERINE
# 51   CANNES MANDELIEU
# 52   CARCASSONNE SALVEZA (PAYS CATHARE)
# 53   CASTRES MAZAMET
# 54   CHALON CHAMPFORGEUIL
# 55   CHAMBERY AIX-LES-BAINS
# 56   CHARLEVILLE MEZIERES
# 57   CHERBOURG MAUPERTUIS
# 58   CLERMONT-FERRAND AULNAT
# 59   COLMAR HOUSSEN
# 60   COURCHEVEL
# 61   DIEPPE SAINT-AUBIN
# 62   DIJON LONVIC  (DIJON BOURGOGNE)
# 63   DOLE TAVAUX
# 64   EPINAL MIRECOURT
# 65   FIGARI SUD CORSE
# 66   GAP TALLARD
# 67   GRANVILLE
# 68   GRAY
# 69   GRENOBLE SAINT-GEOIRS
# 70   HYERES LE PALIVESTRE (TOULON HYERES)
# 71   ISSY-LES-MOULINEAUX
# 72   LANNION
# 73   LAVAL ENTRAMMES
# 74   LIMOGES BELLEGARDE
# 75   LOGNES EMERAINVILLE
# 76   LORIENT LANN-BIHOUE
# 77   LYON BRON
# 78   LA MOLE SAINT-TROPEZ
# 79   LA ROCHELLE LALEU  (LA ROCHELLE ILE DE RE)
# 80   LE BOURGET
# 81   LE CASTELLET
# 82   LE HAVRE OCTEVILLE
# 83   LE MANS ARNAGE
# 84   LE TOUQUET PARIS-PLAGE (COTE D'OPALE)
# 85   MEAUX ESBLY
# 86   MEGEVE
# 87   MONTBELIARD COURCELLES
# 88   NANCY ESSEY
# 89   NEVERS FOURCHAMBAULT
# 90   NIMES GARONS
# 91   ORLEANS BRICY
# 92   ORLEANS SAINT-DENIS-DE-L'HOTEL
# 93   PAU PYRENEES
# 94   PERIGUEUX BASSILLAC
# 95   PERPIGNAN RIVESALTES
# 96   POITIERS BIARD
# 97   PONTARLIER
# 98   PONTOISE CORMEILLES-EN-VEXIN
# 99   QUIMPER PLUGUFFAN (QUIMPER CORNOUAILLES)
# 100  REIMS CHAMPAGNE
# 101  RENNES SAINT-JACQUES
# 102  ROANNE RENAISON
# 103  RODEZ MARCILLAC
# 104  ROUEN VALLEE DE SEINE
# 105  SAINT-ETIENNE BOUTHEON
# 106  SAINT-NAZAIRE MONTOIR
# 107  SAINT YAN
# 108  TARBES LOURDES PYRENEES
# 109  TOURS VAL DE LOIRE
# 110  TROYES BARBEREY
# 111  VALENCE CHABEUIL
# 112  VALENCIENNES DENAIN
# 113  VANNES MEUCON  (VANNES GOLFE DU MORBIHAN)
# 114  VESOUL FROTEY
# 115  VICHY CHARMEILLES
#
#                    office_name office_code        traffic iata_code icao_code  \
# 0    AGEN                       FR005130    AIRPORT (AIR)  AGF       LFBA
# 1    BALE MULHOUSE AEROPORT     FR000340    AIRPORT (AIR)  BSL MLH   LFBD
# 2    BORDEAUX MERIGNAC          FR000600    AIRPORT (AIR)  BOD       LFBD
# 3    BREST                      FR000690    AIRPORT (AIR)  BES       LFRB
# 4    CHATEAUROUX                FR000910    AIRPORT (AIR)  CHR       LFLX
# 5    CAEN                       FR000720    AIRPORT (AIR)  DOL       LFRG
# 6    SAINT-MALO                 FR004060    AIRPORT (AIR)  DNR       LFRD
# 7    ROUEN PORT                 FR003920    AIRPORT (AIR)  DPE       LFAB
# 8    LESQUIN                    FR005350    AIRPORT (AIR)  LIL       LFQQ
# 9    LYON AEROPORT              FR002650    AIRPORT (AIR)  LYS       LFLL
# 10   MARIGNANE AEROPORT         FR002710    AIRPORT (AIR)  MRS       LFML
# 11   ENNERY                     FR001280    AIRPORT (AIR)  ETZ       LFJL
# 12   MONTPELLIER MEDITERRANEE   FR006710    AIRPORT (AIR)  MPL       LFMT
# 13   BREST                      FR000690    AIRPORT (AIR)  MXN       LFRU
# 14   NANTES ATLANTIQUE          FR003030    AIRPORT (AIR)  NTE       LFRS
# 15   NICE AEROPORT              FR003080    AIRPORT (AIR)  NCE       LFMN
# 16   ORLY                       FR003370    AIRPORT (AIR)  ORY       LFPO
# 17   ROISSY PRISE EN CHARGE     FR00677A    AIRPORT (AIR)  CDG       LFPG
# 18   SAINT-BRIEUC               FR002310    AIRPORT (AIR)  SBK       LFRT
# 19   STRASBOURG ENTZHEIM        FR004310    AIRPORT (AIR)  SXB       LFST
# 20   TOULOUSE BLAGNAC AEROPORT  FR004440    AIRPORT (AIR)  TLS       LFBO
# 21   REIMS                      FR003790    AIRPORT (AIR)  XCR       LFOK
# 22   LE RAIZET AEROPORT         FR006330    AIRPORT (AIR)  PTP       TFFR
# 23   LE LAMENTIN AEROPORT       FR006440    AIRPORT (AIR)  FDF       TFFF
# 24   SAINT-DENIS AEROPORT       FR006460    AIRPORT (AIR)  RUN       FMEE
# 25   SAINT-PIERRE               FR006430    AIRPORT (AIR)  ZSE       FMEP
# 26   PAMANDZI                   FR006810    AIRPORT (AIR)  DZA       FMCZ
# 27   AMIENS                     FR000100    AIRPORT (AIR)  NaN       LFOI
# 28   AJACCIO PORT               FR000040    AIRPORT (AIR)  AJA       LFKJ
# 29   AMIENS                     FR000100    AIRPORT (AIR)  NaN       NaN
# 30   ALBI                       FR005800    AIRPORT (AIR)  LBI       LFCI
# 31   AMIENS                     FR000100    AIRPORT (AIR)  NaN       LFAY
# 32   ANGERS                     FR000120    AIRPORT (AIR)  ANE       LFJR
# 33   ANGOULEME                  FR000130    AIRPORT (AIR)  ANG       LFBU
# 34   ANNECY                     FR000140    AIRPORT (AIR)  NCY       LFLP
# 35   VALLARD-THONEX             FR006670    AIRPORT (AIR)  NaN       LFLI
# 36   AUXERRE                    FR005500    AIRPORT (AIR)  AUF       LFLA
# 37   AVIGNON                    FR000270    AIRPORT (AIR)  AVN       LFMV
# 38   BASTIA PORT                FR000380    AIRPORT (AIR)  BIA       LFKB
# 39   BAYONNE                    FR000390    AIRPORT (AIR)  BIQ       LFBZ
# 40   COMPIEGNE                  FR004990    AIRPORT (AIR)  BVA       LFOB
# 41   BASSENS                    FR000610    AIRPORT (AIR)  NaN       NaN
# 42   BESANCON                   FR000460    AIRPORT (AIR)  NaN       LFQM
# 43   SETE                       FR004250    AIRPORT (AIR)  BZR       LFMU
# 44   BLOIS                      FR000530    AIRPORT (AIR)  NaN       LFOQ
# 45   BOURGES                    FR000640    AIRPORT (AIR)  BOU       LFLD
# 46   BRIVE                      FR004960    AIRPORT (AIR)  BVE       LFBV
# 47   CAEN                       FR000720    AIRPORT (AIR)  CFR       LFRK
# 48   CAHORS                     FR005470    AIRPORT (AIR)  ZAO       LFCC
# 49   BOULOGNE                   FR000630    AIRPORT (AIR)  CQF       LFAC
# 50   BASTIA PORT                FR000380    AIRPORT (AIR)  CLY       LFKC
# 51   NICE AEROPORT              FR003080    AIRPORT (AIR)  CEQ       LFMD
# 52   PORT-LA-NOUVELLE           FR003650    AIRPORT (AIR)  CCF       LFMK
# 53   ALBI                       FR005800    AIRPORT (AIR)  DCM       LFCK
# 54   CHALON-SUR-SAONE           FR000860    AIRPORT (AIR)  NaN       LFLH
# 55   CHAMBERY                   FR000870    AIRPORT (AIR)  CMF       LFLB
# 56   CHARLEVILLE                FR000900    AIRPORT (AIR)  NaN       LFQV
# 57   CAEN                       FR000720    AIRPORT (AIR)  CER       LFRC
# 58   CLERMONT-FERRRAND          FR000980    AIRPORT (AIR)  CFE       LFLC
# 59   MULHOUSE                   FR002990    AIRPORT (AIR)  CMR       LFGA
# 60   CHAMBERY                   FR000870    AIRPORT (AIR)  CVF       LFLJ
# 61   ROUEN PORT                 FR003920    AIRPORT (AIR)  DPE       LFAB
# 62   DIJON                      FR001170    AIRPORT (AIR)  DIJ       LFGI
# 63   LONS-LE-SAULNIER           FR005260    AIRPORT (AIR)  DLE       LFGJ
# 64   EPINAL                     FR001290    AIRPORT (AIR)  EPL       LFSG
# 65   AJACCIO PORT               FR000040    AIRPORT (AIR)  FSC       LFKF
# 66   GAP                        FR005830    AIRPORT (AIR)  GAT       LFNA
# 67   CAEN                       FR000720    AIRPORT (AIR)  GFR       LFRF
# 68   BESANCON                   FR000460    AIRPORT (AIR)  NaN       LFEV
# 69   GRENOBLE                   FR001610    AIRPORT (AIR)  GNB       LFLS
# 70   TOULON                     FR004430    AIRPORT (AIR)  JLN       LFTH
# 71   GENNEVILLIERS              FR003410    AIRPORT (AIR)  JDP       LFPI
# 72   SAINT-BRIEUC               FR002310    AIRPORT (AIR)  LAI       LFRO
# 73   ANGERS                     FR000120    AIRPORT (AIR)  LVA       LFOV
# 74   LIMOGES                    FR002540    AIRPORT (AIR)  LIG       LFBL
# 75   MARNE-LA-VALLEE            FR006270    AIRPORT (AIR)  NaN       LFPL
# 76   LORIENT                    FR002600    AIRPORT (AIR)  LRT       LFRH
# 77   LYON AEROPORT              FR002650    AIRPORT (AIR)  LYN       LFLY
# 78   TOULON                     FR004430    AIRPORT (AIR)  NaN       LFTZ
# 79   LA ROCHELLE PALLICE        FR002090    AIRPORT (AIR)  LRH       LFBH
# 80   ROISSY PRISE EN CHARGE     FR00677A    AIRPORT (AIR)  LBG       LFPB
# 81   TOULON                     FR004430    AIRPORT (AIR)  CTT       LFMQ
# 82   LE HAVRE PORT              FR002300    AIRPORT (AIR)  LEH       LFOH
# 83   LE MANS                    FR002340    AIRPORT (AIR)  LME       LFRM
# 84   BOULOGNE                   FR000630    AIRPORT (AIR)  LTQ       LFAT
# 85   MARNE-LA-VALLEE            FR006270    AIRPORT (AIR)  NaN       LFPE
# 86   ANNECY                     FR000140    AIRPORT (AIR)  MVV       LFHM
# 87   DELLE                      FR001140    AIRPORT (AIR)  NaN       LFSM
# 88   NANCY                      FR003000    AIRPORT (AIR)  ENC       LFSN
# 89   AUXERRE                    FR005500    AIRPORT (AIR)  NVS       LFQG
# 90   NIMES                      FR003120    AIRPORT (AIR)  FNI       LFTW
# 91   ORLEANS                    FR003160    AIRPORT (AIR)  ORE       LFOJ
# 92   ORLEANS                    FR003160    AIRPORT (AIR)  NaN       LFOZ
# 93   PAU                        FR003440    AIRPORT (AIR)  PUF       LFBP
# 94   PERIGUEUX                  FR004910    AIRPORT (AIR)  PGX       LFBX
# 95   PERPIGNAN                  FR003480    AIRPORT (AIR)  PGF       LFMP
# 96   POITIERS                   FR003540    AIRPORT (AIR)  PIS       LFBI
# 97   PONTARLIER                 FR003550    AIRPORT (AIR)  NaN       LFSP
# 98   GENNEVILLIERS              FR003410    AIRPORT (AIR)  JDP       LFPI
# 99   BREST                      FR000690    AIRPORT (AIR)  UIP       LFRQ
# 100  REIMS                      FR003790    AIRPORT (AIR)  RHE       LFSR
# 101  RENNES                     FR003800    AIRPORT (AIR)  RNS       LFRN
# 102  SAINT-ETIENNE AEROPORT     FR003970    AIRPORT (AIR)  RNE       LFLO
# 103  TOULOUSE BLAGNAC AEROPORT  FR004440    AIRPORT (AIR)  TLS       LFBO
# 104  ROUEN PORT                 FR003920    AIRPORT (AIR)  URO       LFOP
# 105  SAINT ETIENNE AEROPORT     FR003970    AIRPORT (AIR)  EBU       LFMH
# 106  SAINT-NAZAIRE MONTOIR      FR004080    AIRPORT (AIR)  SNR       LFRZ
# 107  CHALON-SUR-SAONE           FR000860    AIRPORT (AIR)  SYT       LFLN
# 108  TARBES                     FR004350    AIRPORT (AIR)  LDE       LFBT
# 109  TOURS                      FR004490    AIRPORT (AIR)  TUF       LFOT
# 110  TROYES                     FR004520    AIRPORT (AIR)  NaN       LFQB
# 111  VALENCE                    FR004550    AIRPORT (AIR)  VAF       LFLU
# 112  VALENCIENNES               FR004560    AIRPORT (AIR)  NaN       LFAV
# 113  LORIENT                    FR002600    AIRPORT (AIR)  VNE       LFRV
# 114  BESANCON                   FR000460    AIRPORT (AIR)  NaN       LFQW
# 115  MOULINS                    FR005750    AIRPORT (AIR)  VHY       LFLV
#
#                                             airport_type territory
# 0    AIRPORT WITH THIRD COUNTRY FREIGHT TRAFFIC           MAINLAND
# 1    AIRPORT WITH THIRD COUNTRY FREIGHT TRAFFIC           MAINLAND
# 2    AIRPORT WITH THIRD COUNTRY FREIGHT TRAFFIC           MAINLAND
# 3    AIRPORT WITH THIRD COUNTRY FREIGHT TRAFFIC           MAINLAND
# 4    AIRPORT WITH THIRD COUNTRY FREIGHT TRAFFIC           MAINLAND
# 5    AIRPORT WITH THIRD COUNTRY FREIGHT TRAFFIC           MAINLAND
# 6    AIRPORT WITH THIRD COUNTRY FREIGHT TRAFFIC           MAINLAND
# 7    AIRPORT WITH THIRD COUNTRY FREIGHT TRAFFIC           MAINLAND
# 8    AIRPORT WITH THIRD COUNTRY FREIGHT TRAFFIC           MAINLAND
# 9    AIRPORT WITH THIRD COUNTRY FREIGHT TRAFFIC           MAINLAND
# 10   AIRPORT WITH THIRD COUNTRY FREIGHT TRAFFIC           MAINLAND
# 11   AIRPORT WITH THIRD COUNTRY FREIGHT TRAFFIC           MAINLAND
# 12   AIRPORT WITH THIRD COUNTRY FREIGHT TRAFFIC           MAINLAND
# 13   AIRPORT WITH THIRD COUNTRY FREIGHT TRAFFIC           MAINLAND
# 14   AIRPORT WITH THIRD COUNTRY FREIGHT TRAFFIC           MAINLAND
# 15   AIRPORT WITH THIRD COUNTRY FREIGHT TRAFFIC           MAINLAND
# 16   AIRPORT WITH THIRD COUNTRY FREIGHT TRAFFIC           MAINLAND
# 17   AIRPORT WITH THIRD COUNTRY FREIGHT TRAFFIC           MAINLAND
# 18   AIRPORT WITH THIRD COUNTRY FREIGHT TRAFFIC           MAINLAND
# 19   AIRPORT WITH THIRD COUNTRY FREIGHT TRAFFIC           MAINLAND
# 20   AIRPORT WITH THIRD COUNTRY FREIGHT TRAFFIC           MAINLAND
# 21   AIRPORT WITH THIRD COUNTRY FREIGHT TRAFFIC           MAINLAND
# 22   AIRPORT WITH THIRD COUNTRY FREIGHT TRAFFIC           OVERSEAS
# 23   AIRPORT WITH THIRD COUNTRY FREIGHT TRAFFIC           OVERSEAS
# 24   AIRPORT WITH THIRD COUNTRY FREIGHT TRAFFIC           OVERSEAS
# 25   AIRPORT WITH THIRD COUNTRY FREIGHT TRAFFIC           OVERSEAS
# 26   AIRPORT WITH THIRD COUNTRY FREIGHT TRAFFIC           OVERSEAS
# 27   AIRPORT AUTHORIZED TO RECEIVE THIRD COUNTRY FREIGHT  MAINLAND
# 28   AIRPORT AUTHORIZED TO RECEIVE THIRD COUNTRY FREIGHT  MAINLAND
# 29   AIRPORT AUTHORIZED TO RECEIVE THIRD COUNTRY FREIGHT  MAINLAND
# 30   AIRPORT AUTHORIZED TO RECEIVE THIRD COUNTRY FREIGHT  MAINLAND
# 31   AIRPORT AUTHORIZED TO RECEIVE THIRD COUNTRY FREIGHT  MAINLAND
# 32   AIRPORT AUTHORIZED TO RECEIVE THIRD COUNTRY FREIGHT  MAINLAND
# 33   AIRPORT AUTHORIZED TO RECEIVE THIRD COUNTRY FREIGHT  MAINLAND
# 34   AIRPORT AUTHORIZED TO RECEIVE THIRD COUNTRY FREIGHT  MAINLAND
# 35   AIRPORT AUTHORIZED TO RECEIVE THIRD COUNTRY FREIGHT  MAINLAND
# 36   AIRPORT AUTHORIZED TO RECEIVE THIRD COUNTRY FREIGHT  MAINLAND
# 37   AIRPORT AUTHORIZED TO RECEIVE THIRD COUNTRY FREIGHT  MAINLAND
# 38   AIRPORT AUTHORIZED TO RECEIVE THIRD COUNTRY FREIGHT  MAINLAND
# 39   AIRPORT AUTHORIZED TO RECEIVE THIRD COUNTRY FREIGHT  MAINLAND
# 40   AIRPORT AUTHORIZED TO RECEIVE THIRD COUNTRY FREIGHT  MAINLAND
# 41   AIRPORT AUTHORIZED TO RECEIVE THIRD COUNTRY FREIGHT  MAINLAND
# 42   AIRPORT AUTHORIZED TO RECEIVE THIRD COUNTRY FREIGHT  MAINLAND
# 43   AIRPORT AUTHORIZED TO RECEIVE THIRD COUNTRY FREIGHT  MAINLAND
# 44   AIRPORT AUTHORIZED TO RECEIVE THIRD COUNTRY FREIGHT  MAINLAND
# 45   AIRPORT AUTHORIZED TO RECEIVE THIRD COUNTRY FREIGHT  MAINLAND
# 46   AIRPORT AUTHORIZED TO RECEIVE THIRD COUNTRY FREIGHT  MAINLAND
# 47   AIRPORT AUTHORIZED TO RECEIVE THIRD COUNTRY FREIGHT  MAINLAND
# 48   AIRPORT AUTHORIZED TO RECEIVE THIRD COUNTRY FREIGHT  MAINLAND
# 49   AIRPORT AUTHORIZED TO RECEIVE THIRD COUNTRY FREIGHT  MAINLAND
# 50   AIRPORT AUTHORIZED TO RECEIVE THIRD COUNTRY FREIGHT  MAINLAND
# 51   AIRPORT AUTHORIZED TO RECEIVE THIRD COUNTRY FREIGHT  MAINLAND
# 52   AIRPORT AUTHORIZED TO RECEIVE THIRD COUNTRY FREIGHT  MAINLAND
# 53   AIRPORT AUTHORIZED TO RECEIVE THIRD COUNTRY FREIGHT  MAINLAND
# 54   AIRPORT AUTHORIZED TO RECEIVE THIRD COUNTRY FREIGHT  MAINLAND
# 55   AIRPORT AUTHORIZED TO RECEIVE THIRD COUNTRY FREIGHT  MAINLAND
# 56   AIRPORT AUTHORIZED TO RECEIVE THIRD COUNTRY FREIGHT  MAINLAND
# 57   AIRPORT AUTHORIZED TO RECEIVE THIRD COUNTRY FREIGHT  MAINLAND
# 58   AIRPORT AUTHORIZED TO RECEIVE THIRD COUNTRY FREIGHT  MAINLAND
# 59   AIRPORT AUTHORIZED TO RECEIVE THIRD COUNTRY FREIGHT  MAINLAND
# 60   AIRPORT AUTHORIZED TO RECEIVE THIRD COUNTRY FREIGHT  MAINLAND
# 61   AIRPORT AUTHORIZED TO RECEIVE THIRD COUNTRY FREIGHT  MAINLAND
# 62   AIRPORT AUTHORIZED TO RECEIVE THIRD COUNTRY FREIGHT  MAINLAND
# 63   AIRPORT AUTHORIZED TO RECEIVE THIRD COUNTRY FREIGHT  MAINLAND
# 64   AIRPORT AUTHORIZED TO RECEIVE THIRD COUNTRY FREIGHT  MAINLAND
# 65   AIRPORT AUTHORIZED TO RECEIVE THIRD COUNTRY FREIGHT  MAINLAND
# 66   AIRPORT AUTHORIZED TO RECEIVE THIRD COUNTRY FREIGHT  MAINLAND
# 67   AIRPORT AUTHORIZED TO RECEIVE THIRD COUNTRY FREIGHT  MAINLAND
# 68   AIRPORT AUTHORIZED TO RECEIVE THIRD COUNTRY FREIGHT  MAINLAND
# 69   AIRPORT AUTHORIZED TO RECEIVE THIRD COUNTRY FREIGHT  MAINLAND
# 70   AIRPORT AUTHORIZED TO RECEIVE THIRD COUNTRY FREIGHT  MAINLAND
# 71   AIRPORT AUTHORIZED TO RECEIVE THIRD COUNTRY FREIGHT  MAINLAND
# 72   AIRPORT AUTHORIZED TO RECEIVE THIRD COUNTRY FREIGHT  MAINLAND
# 73   AIRPORT AUTHORIZED TO RECEIVE THIRD COUNTRY FREIGHT  MAINLAND
# 74   AIRPORT AUTHORIZED TO RECEIVE THIRD COUNTRY FREIGHT  MAINLAND
# 75   AIRPORT AUTHORIZED TO RECEIVE THIRD COUNTRY FREIGHT  MAINLAND
# 76   AIRPORT AUTHORIZED TO RECEIVE THIRD COUNTRY FREIGHT  MAINLAND
# 77   AIRPORT AUTHORIZED TO RECEIVE THIRD COUNTRY FREIGHT  MAINLAND
# 78   AIRPORT AUTHORIZED TO RECEIVE THIRD COUNTRY FREIGHT  MAINLAND
# 79   AIRPORT AUTHORIZED TO RECEIVE THIRD COUNTRY FREIGHT  MAINLAND
# 80   AIRPORT AUTHORIZED TO RECEIVE THIRD COUNTRY FREIGHT  MAINLAND
# 81   AIRPORT AUTHORIZED TO RECEIVE THIRD COUNTRY FREIGHT  MAINLAND
# 82   AIRPORT AUTHORIZED TO RECEIVE THIRD COUNTRY FREIGHT  MAINLAND
# 83   AIRPORT AUTHORIZED TO RECEIVE THIRD COUNTRY FREIGHT  MAINLAND
# 84   AIRPORT AUTHORIZED TO RECEIVE THIRD COUNTRY FREIGHT  MAINLAND
# 85   AIRPORT AUTHORIZED TO RECEIVE THIRD COUNTRY FREIGHT  MAINLAND
# 86   AIRPORT AUTHORIZED TO RECEIVE THIRD COUNTRY FREIGHT  MAINLAND
# 87   AIRPORT AUTHORIZED TO RECEIVE THIRD COUNTRY FREIGHT  MAINLAND
# 88   AIRPORT AUTHORIZED TO RECEIVE THIRD COUNTRY FREIGHT  MAINLAND
# 89   AIRPORT AUTHORIZED TO RECEIVE THIRD COUNTRY FREIGHT  MAINLAND
# 90   AIRPORT AUTHORIZED TO RECEIVE THIRD COUNTRY FREIGHT  MAINLAND
# 91   AIRPORT AUTHORIZED TO RECEIVE THIRD COUNTRY FREIGHT  MAINLAND
# 92   AIRPORT AUTHORIZED TO RECEIVE THIRD COUNTRY FREIGHT  MAINLAND
# 93   AIRPORT AUTHORIZED TO RECEIVE THIRD COUNTRY FREIGHT  MAINLAND
# 94   AIRPORT AUTHORIZED TO RECEIVE THIRD COUNTRY FREIGHT  MAINLAND
# 95   AIRPORT AUTHORIZED TO RECEIVE THIRD COUNTRY FREIGHT  MAINLAND
# 96   AIRPORT AUTHORIZED TO RECEIVE THIRD COUNTRY FREIGHT  MAINLAND
# 97   AIRPORT AUTHORIZED TO RECEIVE THIRD COUNTRY FREIGHT  MAINLAND
# 98   AIRPORT AUTHORIZED TO RECEIVE THIRD COUNTRY FREIGHT  MAINLAND
# 99   AIRPORT AUTHORIZED TO RECEIVE THIRD COUNTRY FREIGHT  MAINLAND
# 100  AIRPORT AUTHORIZED TO RECEIVE THIRD COUNTRY FREIGHT  MAINLAND
# 101  AIRPORT AUTHORIZED TO RECEIVE THIRD COUNTRY FREIGHT  MAINLAND
# 102  AIRPORT AUTHORIZED TO RECEIVE THIRD COUNTRY FREIGHT  MAINLAND
# 103  AIRPORT AUTHORIZED TO RECEIVE THIRD COUNTRY FREIGHT  MAINLAND
# 104  AIRPORT AUTHORIZED TO RECEIVE THIRD COUNTRY FREIGHT  MAINLAND
# 105  AIRPORT AUTHORIZED TO RECEIVE THIRD COUNTRY FREIGHT  MAINLAND
# 106  AIRPORT AUTHORIZED TO RECEIVE THIRD COUNTRY FREIGHT  MAINLAND
# 107  AIRPORT AUTHORIZED TO RECEIVE THIRD COUNTRY FREIGHT  MAINLAND
# 108  AIRPORT AUTHORIZED TO RECEIVE THIRD COUNTRY FREIGHT  MAINLAND
# 109  AIRPORT AUTHORIZED TO RECEIVE THIRD COUNTRY FREIGHT  MAINLAND
# 110  AIRPORT AUTHORIZED TO RECEIVE THIRD COUNTRY FREIGHT  MAINLAND
# 111  AIRPORT AUTHORIZED TO RECEIVE THIRD COUNTRY FREIGHT  MAINLAND
# 112  AIRPORT AUTHORIZED TO RECEIVE THIRD COUNTRY FREIGHT  MAINLAND
# 113  AIRPORT AUTHORIZED TO RECEIVE THIRD COUNTRY FREIGHT  MAINLAND
# 114  AIRPORT AUTHORIZED TO RECEIVE THIRD COUNTRY FREIGHT  MAINLAND
# 115  AIRPORT AUTHORIZED TO RECEIVE THIRD COUNTRY FREIGHT  MAINLAND
