# %% [markdown]
# # LIST OF CUSTOM OFFICES AT THE FRENCH POINTS OF ENTRY INTO THE EUROPEAN UNION (PORTS)
#
# ## *Scraping/Parsing/Cleaning/Reshaping/Translating data from a PDF*
#
#
# The data will be extracted from a PDF containing [a list of the French points of entry into the European Union and their respective custom offices.](https://www.douane.gouv.fr/sites/default/files/uploads/files/Services-en-ligne/ICS/ics-liste-points-d-entree-francais.pdf)
#
# As stated by the French Customs:
#
# >* **"The names of the ports which constitute the first points of entry, or subsequent points, are included here, as well as the codes of the customs offices which are attached to them."**
# * **"The maritime points of entry open to the office of entry-ENT competence experience a traffic subject to the obligations arising from ICS (Import Control System)"**
#
# The data related to ports in the file `ics-liste-points-d-entree-francais.pdf` starts on page 0, ends on page 3, and the table on each page has headers.
#
# The data will be extracted using the [`pdfplumber`](https://github.com/jsvine/pdfplumber) tool.
#
# #### Steps:
# 1. Import dependencies
# 2. Open the PDF and check its structure
# 3. Create an empty data frame and specify the columns
# 4. Create a function to extract data from a single PDF page and return a data frame
# 5. Loop over the pages and call the function on each page
# 6. Find the last table and extract its data
# 7. Clean up and translate the data
# 8. Do one quick bit of basic analysis in pandas
# 9. Write the data to a CSV file

# %% [markdown]
# ### 1. Import dependencies

# %%
import pdfplumber
import pandas as pd

# %%
# Set pandas display options (optional)
pd.set_option("display.max_columns", None)
pd.set_option("display.max_rows", None)
pd.set_option("display.max_colwidth", -1)

# %% [markdown]
# ### 2. Open the PDF and check its structure
# Using `pdfplumber`'s syntax to open a file, explore the PDF structure and extract the ports data table that starts on page 0.

# %%
with pdfplumber.open("ics-liste-points-d-entree-francais.pdf") as pdf:
    # print(pdf)
    #print(pdf.pages)
    test = pdf.pages[0]
    table = test.extract_table()
    print(table)
# Out:
# [["Nom du \npoint d'entrée", 'Nom du \nbureau', 'Code \nbureau', 'Trafic', 'Code\nport'], ['►Vecteur maritime (1)', None, None, None, None], ['Ajaccio', 'Ajaccio', 'FR000040', 'Maritime (P) \nRoutier (R)', 'FRAJA'], ['Bastia', 'Bastia port', 'FR000380', 'Maritime (P) \nRoutier (R)', 'FRBIA'], ['Bayonne', 'Bayonne', 'FR000390', 'Maritime (P) \nRoutier (R)', 'FRBAY'], ['Berre l’Étang (raffinerie)', 'Port-de-Bouc port', 'FR003620', 'Maritime (P) \nRoutier (R)', 'FRETB'], ['Bordeaux', 'Bassens', 'FR000610', 'Maritime (P) \nRoutier (R)', 'FRBAS\nFRBSE'], ['Boulogne-sur-Mer', 'Boulogne', 'FR000630', 'Maritime (P) \nRoutier (R)', 'FRBOL'], ['Brest', 'Brest', 'FR000690', 'Maritime (P) \nRoutier (R)', 'FRBES'], ['Caen Ouistreham', 'Caen', 'FR000720', 'Maritime (P) \nRoutier (R)', 'FRCFR'], ['Calais', 'Boulogne', 'FR000630', 'Maritime (P) \nRoutier (R)', 'FRCQF'], ['Cannes', 'Cannes', 'FR000800', 'Maritime (P) \nRoutier (R)', 'FRCEQ'], ['Cherbourg', 'Caen', 'FR000720', 'Maritime (P) \nRoutier (R)', 'FRCER'], ['Concarneau Douarnenez', 'Brest', 'FR000690', 'Maritime (P) \nRoutier (R)', 'FRCOC\nFRDRZ'], ['Dieppe', 'Rouen port', 'FR003920', 'Maritime (P) \nRoutier (R)', 'FRDPE'], ['Donges raffinerie', 'Donges raffinerie', 'FR001200', 'Maritime (P) \nRoutier (R)', 'FRDON'], ['Dunkerque', 'Dunkerque', 'FR001260', 'Maritime (P) \nRoutier (R)', 'FRDKK'], ['Fécamp', 'Le Havre port', 'FR002300', 'Maritime (P) \nRoutier (R)', 'FRFEC']]

# %% [markdown]
# ### 3. Create an empty data frame and define the columns

# %%
cols = ["point_of_entry_name", "office_name", "office_code", "traffic", "port_code"]

df = pd.DataFrame(columns=cols)

# %% [markdown]
# ### 4. Create a function to extract data from a single PDF page
# This function will be called on every PDF page we hand it. It will take a `pdfplumber.Page` object, extract the table and return the data in a data frame with the same headers as the empty one we just created.

# %%
def page_to_df(page):
    
    # Find the table on the page and extract the data
    table = page.extract_table()
    
    # Grab all rows in the table except for the first one,
    # which is the header row
    lines = table[1:]
    
    # Return the data in a data frame
    return pd.DataFrame(lines, columns=cols)

# %% [markdown]
# ### 5. Loop over the pages and call the function on each page
#
# As we extract the data from each page, we'll append the data frame returned by our function to the empty data frame (`df`) that we created earlier.

# %%
# Open the PDF
with pdfplumber.open("ics-liste-points-d-entree-francais.pdf") as pdf:
    
    # Select only the first 3 pages with the data table containing the list of maritime ports
    pages_with_data = pdf.pages[0:3]
    
    # Loop over the pages with data
    for page in pages_with_data:
        
        # Call the extraction function to grab the data from this page
        df_to_append = page_to_df(page)
        
        # Append it to our main dataframe, chopping off the index column
        df = df.append(df_to_append, ignore_index=True)

# %%
df
# Out:
#               point_of_entry_name                    office_name office_code  \
# 0   ►Vecteur maritime (1)          None                           None
# 1   Ajaccio                        Ajaccio                        FR000040
# 2   Bastia                         Bastia port                    FR000380
# 3   Bayonne                        Bayonne                        FR000390
# 4   Berre l’Étang (raffinerie)     Port-de-Bouc port              FR003620
# 5   Bordeaux                       Bassens                        FR000610
# 6   Boulogne-sur-Mer               Boulogne                       FR000630
# 7   Brest                          Brest                          FR000690
# 8   Caen Ouistreham                Caen                           FR000720
# 9   Calais                         Boulogne                       FR000630
# 10  Cannes                         Cannes                         FR000800
# 11  Cherbourg                      Caen                           FR000720
# 12  Concarneau Douarnenez          Brest                          FR000690
# 13  Dieppe                         Rouen port                     FR003920
# 14  Donges raffinerie              Donges raffinerie              FR001200
# 15  Dunkerque                      Dunkerque                      FR001260
# 16  Fécamp                         Le Havre port                  FR002300
# 17  ►Vecteur maritime (1)          None                           None
# 18  Fos-sur-Mer (raffinerie)       Port-de-Bouc port              FR003620
# 19  Fos Port-Saint-Louis-du-Rhône  Fos Port-Saint-Louis-du-Rhône  FR003680
# 20  Gonfreville raffinerie         Gonfreville raffinerie         FR001560
# 21  Honfleur                       Le Havre port                  FR002300
# 22  La Rochelle Pallice            La Rochelle Pallice            FR002090
# 23  Le Havre                       Le Havre port                  FR002300
# 24  Le Havre Antifer               Le Havre Antifer               FR002270
# 25  La Mède (raffinerie)           Port-de-Bouc port              FR003620
# 26  Lavera (raffinerie)            Port-de-Bouc Port              FR003620
# 27  Le Tréport                     Rouen port                     FR003920
# 28  Les Sables d'Olonnes           La Roche-sur-Yon               FR006240
# 29  Lorient                        Lorient                        FR002600
# 30  Marseille                      Marseille port                 FR002730
# 31  Monaco                         Monaco                         FR002860
# 32  Nantes Atlantique              Nantes Atlantique              FR003030
# 33  Nice port                      Nice aéroport                  FR003080
# 34  Petit Couronne raffinerie      Rouen énergies                 FR003500
# 35  Port-de-Bouc                   Port-de-Bouc port              FR003620
# 36  Port Jérôme raffinerie         Port Jérôme raffinerie         FR003630
# 37  Port-la-Nouvelle               Port-la-Nouvelle               FR003650
# 38  Port Vendres                   Port Vendres                   FR003690
# 39  Porto-Vecchio                  Ajaccio                        FR000040
# 40  ►Vecteur maritime (1)          None                           None
# 41  Rochefort Tonnay-Charente      La Rochelle Pallice            FR002090
# 42  Rouen                          Rouen port                     FR003920
# 43  Saint-Brieuc Le Légué          Saint-Brieuc                   FR002310
# 44  Saint-Malo                     Saint-Malo                     FR004060
# 45  Saint-Nazaire Montoir          Saint-Nazaire Montoir          FR004080
# 46  Sète                           Sète                           FR004250
# 47  Toulon La Seyne                Toulon La Seyne                FR004430
# 48  DOM                            None                           None
# 49  Basse-Terre (Guadeloupe)       La Pointe Jarry                FR006610
# 50  Fort-de-France (Martinique)    Fort-de-France port            FR006340
# 51  Kourou (Guyane)                Degrad des Cannes              FR006370
# 52  La Pointe Jarry (Guadeloupe)   La Pointe Jarry                FR006610
# 53  Le Port (La Réunion)           Le Port                        FR006420
# 54  Le Robert (Martinique)         Fort-de-France port            FR006340
# 55  Pointe-à-Pitre (Guadeloupe)    La Pointe Jarry                FR006610
# 56  Saint-Pierre (Martinique)      Fort-de-France port            FR006340
# 57  Longoni (Mayotte)              Longoni port                   FR006800
# 58  Dzaoudzi (Mayotte)             Pamandzi                       FR006810
# 59  ►Vecteur fluvio-maritime       None                           None
# 60  Chalon-sur-Saône               Chalon-sur-Saône               FR000860
# 61  Gennevilliers                  Gennevilliers                  FR003410
# 62  Gron                           Auxerre                        FR005500
#
#                        traffic            port_code
# 0   None                        None
# 1   Maritime (P) \nRoutier (R)  FRAJA
# 2   Maritime (P) \nRoutier (R)  FRBIA
# 3   Maritime (P) \nRoutier (R)  FRBAY
# 4   Maritime (P) \nRoutier (R)  FRETB
# 5   Maritime (P) \nRoutier (R)  FRBAS\nFRBSE
# 6   Maritime (P) \nRoutier (R)  FRBOL
# 7   Maritime (P) \nRoutier (R)  FRBES
# 8   Maritime (P) \nRoutier (R)  FRCFR
# 9   Maritime (P) \nRoutier (R)  FRCQF
# 10  Maritime (P) \nRoutier (R)  FRCEQ
# 11  Maritime (P) \nRoutier (R)  FRCER
# 12  Maritime (P) \nRoutier (R)  FRCOC\nFRDRZ
# 13  Maritime (P) \nRoutier (R)  FRDPE
# 14  Maritime (P) \nRoutier (R)  FRDON
# 15  Maritime (P) \nRoutier (R)  FRDKK
# 16  Maritime (P) \nRoutier (R)  FRFEC
# 17  None                        None
# 18  Maritime (P) \nRoutier (R)  FRFOS
# 19  Maritime (P) \nRoutier (R)  FRFOS
# 20  Maritime (P) \nRoutier (R)  FRGLO
# 21  Maritime (P) \nRoutier (R)  FRHON
# 22  Maritime (P) \nRoutier (R)  FRLRH
# 23  Maritime (P) \nRoutier (R)  FRLEH
# 24  Maritime (P) \nRoutier (R)  FRLEH
# 25  Maritime (P) \nRoutier (R)  FRLMD
# 26  Maritime (P) \nRoutier (R)  FRLAV
# 27  Maritime (P) \nRoutier (R)  FRLTR
# 28  Maritime (P) \nRoutier (R)  FRLSO
# 29  Maritime (P) \nRoutier (R)  FRLRT
# 30  Maritime (P) \nRoutier (R)  FRMRS
# 31  Maritime (P) \nRoutier (R)  MCMON
# 32  Maritime (P) \nRoutier (R)  FRNTE
# 33  Maritime (P) \nRoutier (R)  FRNCE
# 34  Maritime (P) \nRoutier (R)  FRPET
# 35  Maritime (P) \nRoutier (R)  FRPDB
# 36  Maritime (P) \nRoutier (R)  FRPJE
# 37  Maritime (P) \nRoutier (R)  FRNOU
# 38  Maritime (P) \nRoutier (R)  FRPOV
# 39  Maritime (P) \nRoutier (R)  FRPVO
# 40  None                        None
# 41  Maritime (P) \nRoutier (R)  FRRCC\nFRRCO\nFRRCS
# 42  Maritime (P) \nRoutier (R)  FRURO
# 43  Maritime (P) \nRoutier (R)  FRSPK
# 44  Maritime (P) \nRoutier (R)  FRSML
# 45  Maritime (P) \nRoutier (R)  FRSNG\nFRSNP\nFRSNR
# 46  Maritime (P) \nRoutier (R)  FRSET
# 47  Maritime (P) \nRoutier (R)  FRTOA
# 48  None                        None
# 49  Maritime (P) \nRoutier (R)  GPPTP
# 50  Maritime (P) \nRoutier (R)  MQFDF
# 51  Maritime (P) \nRoutier (R)  GFCAY
# 52  Maritime (P) \nRoutier (R)  GPPTP
# 53  Maritime (P) \nRoutier (R)  RELPT
# 54  Maritime (P) \nRoutier (R)
# 55  Maritime (P) \nRoutier (R)  GPPTP
# 56  Maritime (P)\nRoutier (R)   MQSPI
# 57  Maritime (P)\nRoutier (R)   YTLON
# 58  Maritime (P) \nRoutier (R)  YTDZA
# 59  None                        None
# 60  Maritime (P)\nFluvial (C)   FRCAO
# 61  Maritime (P)\nFluvial (C)   FRGVL
# 62  Maritime (P)\nFluvial (C)   FRGRO

# %% [markdown]
# ### 6. Find the last table and extract its data
#
# The last table of the list of maritime ports lies on page 4 of the PDF, along with the first table of the list of airports which is built on a different format.
#
# We need to only select page 4 then grab the data from the first table on that page.

# %%
# Select only page 4 ([3]) of the PDF containing the last table of the list of maritime ports
last_page = pdf.pages[3]

# Search for all tables on the page
tables = last_page.find_tables()
    
# Select only the first table on the page
last_page_data = tables[0].extract(x_tolerance = 5)

# %%
# Check that the data from the last table have been extracted
last_page_data
# Out:
# [["Nom du \npoint d'entrée",
#   'Nom du \nbureau',
#   'Code \nbureau',
#   'Trafic',
#   'Code\nport'],
#  ['►Vecteur fluvio-maritime', None, None, None, None],
#  ['Lyon port Edouard Herriot',
#   'Lyon aéroport',
#   'FR002650',
#   'Maritime (P)\nFluvial (C)',
#   'FRLIO'],
#  ['Mâcon',
#   'Chalon-sur-Saône',
#   'FR000860',
#   'Maritime (P)\nFluvial (C)',
#   'FRMAC'],
#  ['Salaise-sur-Sanne',
#   "L'Isle d'Abeau",
#   'FR002030',
#   'Maritime (P)\nFluvial (C)',
#   'FRSAL'],
#  ['Valence',
#   'Valence',
#   'FR004550',
#   'Maritime (P)\nFluvial (C)',
#   'FRVAA\nFRVAC\nFRVAF'],
#  ['Villefranche-sur-Saône',
#   'Lyon aéroport',
#   'FR002650',
#   'Maritime (P)\nFluvial (C)',
#   'FRVSS'],
#  ['DOM', None, None, None, None],
#  ['Degrad des Cannes (Guyane)',
#   'Degrad des Cannes',
#   'FR006370',
#   'Maritime (P) \nFluvial (C)\nRoutier (R)',
#   'GFCAY'],
#  ['Saint-Laurent du Maroni (Guyane)',
#   'Saint-Laurent du Maroni',
#   'FR006390',
#   'Maritime (P) \nFluvial (C)\nRoutier (R)(2)',
#   'GFSLM'],
#  ["Saint-Georges de l'Oyapock",
#   "Saint-Georges de l'Oyapock",
#   'FR006750',
#   'Maritime (P)\nFluvial (C)\nRoutier (R)',
#   'GFOYP']]

# %%
# Convert the data extracted inside `last_page_data` into a dataframe called `df2`
df2 = pd.DataFrame(last_page_data, columns=cols)

# %%
df2
# Out:
#                  point_of_entry_name                 office_name  \
# 0   Nom du \npoint d'entrée           Nom du \nbureau
# 1   ►Vecteur fluvio-maritime          None
# 2   Lyon port Edouard Herriot         Lyon aéroport
# 3   Mâcon                             Chalon-sur-Saône
# 4   Salaise-sur-Sanne                 L'Isle d'Abeau
# 5   Valence                           Valence
# 6   Villefranche-sur-Saône            Lyon aéroport
# 7   DOM                               None
# 8   Degrad des Cannes (Guyane)        Degrad des Cannes
# 9   Saint-Laurent du Maroni (Guyane)  Saint-Laurent du Maroni
# 10  Saint-Georges de l'Oyapock        Saint-Georges de l'Oyapock
#
#       office_code                                     traffic  \
# 0   Code \nbureau  Trafic
# 1   None           None
# 2   FR002650       Maritime (P)\nFluvial (C)
# 3   FR000860       Maritime (P)\nFluvial (C)
# 4   FR002030       Maritime (P)\nFluvial (C)
# 5   FR004550       Maritime (P)\nFluvial (C)
# 6   FR002650       Maritime (P)\nFluvial (C)
# 7   None           None
# 8   FR006370       Maritime (P) \nFluvial (C)\nRoutier (R)
# 9   FR006390       Maritime (P) \nFluvial (C)\nRoutier (R)(2)
# 10  FR006750       Maritime (P)\nFluvial (C)\nRoutier (R)
#
#               port_code
# 0   Code\nport
# 1   None
# 2   FRLIO
# 3   FRMAC
# 4   FRSAL
# 5   FRVAA\nFRVAC\nFRVAF
# 6   FRVSS
# 7   None
# 8   GFCAY
# 9   GFSLM
# 10  GFOYP

# %%
# Append the last table of data (`df2`) to our main dataframe `df`
df = df.append(df2, ignore_index=True)

df
# Out:
#                  point_of_entry_name                    office_name  \
# 0   ►Vecteur maritime (1)             None
# 1   Ajaccio                           Ajaccio
# 2   Bastia                            Bastia port
# 3   Bayonne                           Bayonne
# 4   Berre l’Étang (raffinerie)        Port-de-Bouc port
# 5   Bordeaux                          Bassens
# 6   Boulogne-sur-Mer                  Boulogne
# 7   Brest                             Brest
# 8   Caen Ouistreham                   Caen
# 9   Calais                            Boulogne
# 10  Cannes                            Cannes
# 11  Cherbourg                         Caen
# 12  Concarneau Douarnenez             Brest
# 13  Dieppe                            Rouen port
# 14  Donges raffinerie                 Donges raffinerie
# 15  Dunkerque                         Dunkerque
# 16  Fécamp                            Le Havre port
# 17  ►Vecteur maritime (1)             None
# 18  Fos-sur-Mer (raffinerie)          Port-de-Bouc port
# 19  Fos Port-Saint-Louis-du-Rhône     Fos Port-Saint-Louis-du-Rhône
# 20  Gonfreville raffinerie            Gonfreville raffinerie
# 21  Honfleur                          Le Havre port
# 22  La Rochelle Pallice               La Rochelle Pallice
# 23  Le Havre                          Le Havre port
# 24  Le Havre Antifer                  Le Havre Antifer
# 25  La Mède (raffinerie)              Port-de-Bouc port
# 26  Lavera (raffinerie)               Port-de-Bouc Port
# 27  Le Tréport                        Rouen port
# 28  Les Sables d'Olonnes              La Roche-sur-Yon
# 29  Lorient                           Lorient
# 30  Marseille                         Marseille port
# 31  Monaco                            Monaco
# 32  Nantes Atlantique                 Nantes Atlantique
# 33  Nice port                         Nice aéroport
# 34  Petit Couronne raffinerie         Rouen énergies
# 35  Port-de-Bouc                      Port-de-Bouc port
# 36  Port Jérôme raffinerie            Port Jérôme raffinerie
# 37  Port-la-Nouvelle                  Port-la-Nouvelle
# 38  Port Vendres                      Port Vendres
# 39  Porto-Vecchio                     Ajaccio
# 40  ►Vecteur maritime (1)             None
# 41  Rochefort Tonnay-Charente         La Rochelle Pallice
# 42  Rouen                             Rouen port
# 43  Saint-Brieuc Le Légué             Saint-Brieuc
# 44  Saint-Malo                        Saint-Malo
# 45  Saint-Nazaire Montoir             Saint-Nazaire Montoir
# 46  Sète                              Sète
# 47  Toulon La Seyne                   Toulon La Seyne
# 48  DOM                               None
# 49  Basse-Terre (Guadeloupe)          La Pointe Jarry
# 50  Fort-de-France (Martinique)       Fort-de-France port
# 51  Kourou (Guyane)                   Degrad des Cannes
# 52  La Pointe Jarry (Guadeloupe)      La Pointe Jarry
# 53  Le Port (La Réunion)              Le Port
# 54  Le Robert (Martinique)            Fort-de-France port
# 55  Pointe-à-Pitre (Guadeloupe)       La Pointe Jarry
# 56  Saint-Pierre (Martinique)         Fort-de-France port
# 57  Longoni (Mayotte)                 Longoni port
# 58  Dzaoudzi (Mayotte)                Pamandzi
# 59  ►Vecteur fluvio-maritime          None
# 60  Chalon-sur-Saône                  Chalon-sur-Saône
# 61  Gennevilliers                     Gennevilliers
# 62  Gron                              Auxerre
# 63  Nom du \npoint d'entrée           Nom du \nbureau
# 64  ►Vecteur fluvio-maritime          None
# 65  Lyon port Edouard Herriot         Lyon aéroport
# 66  Mâcon                             Chalon-sur-Saône
# 67  Salaise-sur-Sanne                 L'Isle d'Abeau
# 68  Valence                           Valence
# 69  Villefranche-sur-Saône            Lyon aéroport
# 70  DOM                               None
# 71  Degrad des Cannes (Guyane)        Degrad des Cannes
# 72  Saint-Laurent du Maroni (Guyane)  Saint-Laurent du Maroni
# 73  Saint-Georges de l'Oyapock        Saint-Georges de l'Oyapock
#
#       office_code                                     traffic  \
# 0   None           None
# 1   FR000040       Maritime (P) \nRoutier (R)
# 2   FR000380       Maritime (P) \nRoutier (R)
# 3   FR000390       Maritime (P) \nRoutier (R)
# 4   FR003620       Maritime (P) \nRoutier (R)
# 5   FR000610       Maritime (P) \nRoutier (R)
# 6   FR000630       Maritime (P) \nRoutier (R)
# 7   FR000690       Maritime (P) \nRoutier (R)
# 8   FR000720       Maritime (P) \nRoutier (R)
# 9   FR000630       Maritime (P) \nRoutier (R)
# 10  FR000800       Maritime (P) \nRoutier (R)
# 11  FR000720       Maritime (P) \nRoutier (R)
# 12  FR000690       Maritime (P) \nRoutier (R)
# 13  FR003920       Maritime (P) \nRoutier (R)
# 14  FR001200       Maritime (P) \nRoutier (R)
# 15  FR001260       Maritime (P) \nRoutier (R)
# 16  FR002300       Maritime (P) \nRoutier (R)
# 17  None           None
# 18  FR003620       Maritime (P) \nRoutier (R)
# 19  FR003680       Maritime (P) \nRoutier (R)
# 20  FR001560       Maritime (P) \nRoutier (R)
# 21  FR002300       Maritime (P) \nRoutier (R)
# 22  FR002090       Maritime (P) \nRoutier (R)
# 23  FR002300       Maritime (P) \nRoutier (R)
# 24  FR002270       Maritime (P) \nRoutier (R)
# 25  FR003620       Maritime (P) \nRoutier (R)
# 26  FR003620       Maritime (P) \nRoutier (R)
# 27  FR003920       Maritime (P) \nRoutier (R)
# 28  FR006240       Maritime (P) \nRoutier (R)
# 29  FR002600       Maritime (P) \nRoutier (R)
# 30  FR002730       Maritime (P) \nRoutier (R)
# 31  FR002860       Maritime (P) \nRoutier (R)
# 32  FR003030       Maritime (P) \nRoutier (R)
# 33  FR003080       Maritime (P) \nRoutier (R)
# 34  FR003500       Maritime (P) \nRoutier (R)
# 35  FR003620       Maritime (P) \nRoutier (R)
# 36  FR003630       Maritime (P) \nRoutier (R)
# 37  FR003650       Maritime (P) \nRoutier (R)
# 38  FR003690       Maritime (P) \nRoutier (R)
# 39  FR000040       Maritime (P) \nRoutier (R)
# 40  None           None
# 41  FR002090       Maritime (P) \nRoutier (R)
# 42  FR003920       Maritime (P) \nRoutier (R)
# 43  FR002310       Maritime (P) \nRoutier (R)
# 44  FR004060       Maritime (P) \nRoutier (R)
# 45  FR004080       Maritime (P) \nRoutier (R)
# 46  FR004250       Maritime (P) \nRoutier (R)
# 47  FR004430       Maritime (P) \nRoutier (R)
# 48  None           None
# 49  FR006610       Maritime (P) \nRoutier (R)
# 50  FR006340       Maritime (P) \nRoutier (R)
# 51  FR006370       Maritime (P) \nRoutier (R)
# 52  FR006610       Maritime (P) \nRoutier (R)
# 53  FR006420       Maritime (P) \nRoutier (R)
# 54  FR006340       Maritime (P) \nRoutier (R)
# 55  FR006610       Maritime (P) \nRoutier (R)
# 56  FR006340       Maritime (P)\nRoutier (R)
# 57  FR006800       Maritime (P)\nRoutier (R)
# 58  FR006810       Maritime (P) \nRoutier (R)
# 59  None           None
# 60  FR000860       Maritime (P)\nFluvial (C)
# 61  FR003410       Maritime (P)\nFluvial (C)
# 62  FR005500       Maritime (P)\nFluvial (C)
# 63  Code \nbureau  Trafic
# 64  None           None
# 65  FR002650       Maritime (P)\nFluvial (C)
# 66  FR000860       Maritime (P)\nFluvial (C)
# 67  FR002030       Maritime (P)\nFluvial (C)
# 68  FR004550       Maritime (P)\nFluvial (C)
# 69  FR002650       Maritime (P)\nFluvial (C)
# 70  None           None
# 71  FR006370       Maritime (P) \nFluvial (C)\nRoutier (R)
# 72  FR006390       Maritime (P) \nFluvial (C)\nRoutier (R)(2)
# 73  FR006750       Maritime (P)\nFluvial (C)\nRoutier (R)
#
#               port_code
# 0   None
# 1   FRAJA
# 2   FRBIA
# 3   FRBAY
# 4   FRETB
# 5   FRBAS\nFRBSE
# 6   FRBOL
# 7   FRBES
# 8   FRCFR
# 9   FRCQF
# 10  FRCEQ
# 11  FRCER
# 12  FRCOC\nFRDRZ
# 13  FRDPE
# 14  FRDON
# 15  FRDKK
# 16  FRFEC
# 17  None
# 18  FRFOS
# 19  FRFOS
# 20  FRGLO
# 21  FRHON
# 22  FRLRH
# 23  FRLEH
# 24  FRLEH
# 25  FRLMD
# 26  FRLAV
# 27  FRLTR
# 28  FRLSO
# 29  FRLRT
# 30  FRMRS
# 31  MCMON
# 32  FRNTE
# 33  FRNCE
# 34  FRPET
# 35  FRPDB
# 36  FRPJE
# 37  FRNOU
# 38  FRPOV
# 39  FRPVO
# 40  None
# 41  FRRCC\nFRRCO\nFRRCS
# 42  FRURO
# 43  FRSPK
# 44  FRSML
# 45  FRSNG\nFRSNP\nFRSNR
# 46  FRSET
# 47  FRTOA
# 48  None
# 49  GPPTP
# 50  MQFDF
# 51  GFCAY
# 52  GPPTP
# 53  RELPT
# 54
# 55  GPPTP
# 56  MQSPI
# 57  YTLON
# 58  YTDZA
# 59  None
# 60  FRCAO
# 61  FRGVL
# 62  FRGRO
# 63  Code\nport
# 64  None
# 65  FRLIO
# 66  FRMAC
# 67  FRSAL
# 68  FRVAA\nFRVAC\nFRVAF
# 69  FRVSS
# 70  None
# 71  GFCAY
# 72  GFSLM
# 73  GFOYP

# %% [markdown]
# ### 7. Clean up the data

# %%
# Kill line breaks
df.replace("\n", " ", inplace=True, regex=True)
# Out:
#                  point_of_entry_name                    office_name  \
# 0   ►Vecteur maritime (1)             None
# 1   Ajaccio                           Ajaccio
# 2   Bastia                            Bastia port
# 3   Bayonne                           Bayonne
# 4   Berre l’Étang (raffinerie)        Port-de-Bouc port
# 5   Bordeaux                          Bassens
# 6   Boulogne-sur-Mer                  Boulogne
# 7   Brest                             Brest
# 8   Caen Ouistreham                   Caen
# 9   Calais                            Boulogne
# 10  Cannes                            Cannes
# 11  Cherbourg                         Caen
# 12  Concarneau Douarnenez             Brest
# 13  Dieppe                            Rouen port
# 14  Donges raffinerie                 Donges raffinerie
# 15  Dunkerque                         Dunkerque
# 16  Fécamp                            Le Havre port
# 17  ►Vecteur maritime (1)             None
# 18  Fos-sur-Mer (raffinerie)          Port-de-Bouc port
# 19  Fos Port-Saint-Louis-du-Rhône     Fos Port-Saint-Louis-du-Rhône
# 20  Gonfreville raffinerie            Gonfreville raffinerie
# 21  Honfleur                          Le Havre port
# 22  La Rochelle Pallice               La Rochelle Pallice
# 23  Le Havre                          Le Havre port
# 24  Le Havre Antifer                  Le Havre Antifer
# 25  La Mède (raffinerie)              Port-de-Bouc port
# 26  Lavera (raffinerie)               Port-de-Bouc Port
# 27  Le Tréport                        Rouen port
# 28  Les Sables d'Olonnes              La Roche-sur-Yon
# 29  Lorient                           Lorient
# 30  Marseille                         Marseille port
# 31  Monaco                            Monaco
# 32  Nantes Atlantique                 Nantes Atlantique
# 33  Nice port                         Nice aéroport
# 34  Petit Couronne raffinerie         Rouen énergies
# 35  Port-de-Bouc                      Port-de-Bouc port
# 36  Port Jérôme raffinerie            Port Jérôme raffinerie
# 37  Port-la-Nouvelle                  Port-la-Nouvelle
# 38  Port Vendres                      Port Vendres
# 39  Porto-Vecchio                     Ajaccio
# 40  ►Vecteur maritime (1)             None
# 41  Rochefort Tonnay-Charente         La Rochelle Pallice
# 42  Rouen                             Rouen port
# 43  Saint-Brieuc Le Légué             Saint-Brieuc
# 44  Saint-Malo                        Saint-Malo
# 45  Saint-Nazaire Montoir             Saint-Nazaire Montoir
# 46  Sète                              Sète
# 47  Toulon La Seyne                   Toulon La Seyne
# 48  DOM                               None
# 49  Basse-Terre (Guadeloupe)          La Pointe Jarry
# 50  Fort-de-France (Martinique)       Fort-de-France port
# 51  Kourou (Guyane)                   Degrad des Cannes
# 52  La Pointe Jarry (Guadeloupe)      La Pointe Jarry
# 53  Le Port (La Réunion)              Le Port
# 54  Le Robert (Martinique)            Fort-de-France port
# 55  Pointe-à-Pitre (Guadeloupe)       La Pointe Jarry
# 56  Saint-Pierre (Martinique)         Fort-de-France port
# 57  Longoni (Mayotte)                 Longoni port
# 58  Dzaoudzi (Mayotte)                Pamandzi
# 59  ►Vecteur fluvio-maritime          None
# 60  Chalon-sur-Saône                  Chalon-sur-Saône
# 61  Gennevilliers                     Gennevilliers
# 62  Gron                              Auxerre
# 63  Nom du  point d'entrée            Nom du  bureau
# 64  ►Vecteur fluvio-maritime          None
# 65  Lyon port Edouard Herriot         Lyon aéroport
# 66  Mâcon                             Chalon-sur-Saône
# 67  Salaise-sur-Sanne                 L'Isle d'Abeau
# 68  Valence                           Valence
# 69  Villefranche-sur-Saône            Lyon aéroport
# 70  DOM                               None
# 71  Degrad des Cannes (Guyane)        Degrad des Cannes
# 72  Saint-Laurent du Maroni (Guyane)  Saint-Laurent du Maroni
# 73  Saint-Georges de l'Oyapock        Saint-Georges de l'Oyapock
#
#      office_code                                   traffic          port_code
# 0   None          None                                      None
# 1   FR000040      Maritime (P)  Routier (R)                 FRAJA
# 2   FR000380      Maritime (P)  Routier (R)                 FRBIA
# 3   FR000390      Maritime (P)  Routier (R)                 FRBAY
# 4   FR003620      Maritime (P)  Routier (R)                 FRETB
# 5   FR000610      Maritime (P)  Routier (R)                 FRBAS FRBSE
# 6   FR000630      Maritime (P)  Routier (R)                 FRBOL
# 7   FR000690      Maritime (P)  Routier (R)                 FRBES
# 8   FR000720      Maritime (P)  Routier (R)                 FRCFR
# 9   FR000630      Maritime (P)  Routier (R)                 FRCQF
# 10  FR000800      Maritime (P)  Routier (R)                 FRCEQ
# 11  FR000720      Maritime (P)  Routier (R)                 FRCER
# 12  FR000690      Maritime (P)  Routier (R)                 FRCOC FRDRZ
# 13  FR003920      Maritime (P)  Routier (R)                 FRDPE
# 14  FR001200      Maritime (P)  Routier (R)                 FRDON
# 15  FR001260      Maritime (P)  Routier (R)                 FRDKK
# 16  FR002300      Maritime (P)  Routier (R)                 FRFEC
# 17  None          None                                      None
# 18  FR003620      Maritime (P)  Routier (R)                 FRFOS
# 19  FR003680      Maritime (P)  Routier (R)                 FRFOS
# 20  FR001560      Maritime (P)  Routier (R)                 FRGLO
# 21  FR002300      Maritime (P)  Routier (R)                 FRHON
# 22  FR002090      Maritime (P)  Routier (R)                 FRLRH
# 23  FR002300      Maritime (P)  Routier (R)                 FRLEH
# 24  FR002270      Maritime (P)  Routier (R)                 FRLEH
# 25  FR003620      Maritime (P)  Routier (R)                 FRLMD
# 26  FR003620      Maritime (P)  Routier (R)                 FRLAV
# 27  FR003920      Maritime (P)  Routier (R)                 FRLTR
# 28  FR006240      Maritime (P)  Routier (R)                 FRLSO
# 29  FR002600      Maritime (P)  Routier (R)                 FRLRT
# 30  FR002730      Maritime (P)  Routier (R)                 FRMRS
# 31  FR002860      Maritime (P)  Routier (R)                 MCMON
# 32  FR003030      Maritime (P)  Routier (R)                 FRNTE
# 33  FR003080      Maritime (P)  Routier (R)                 FRNCE
# 34  FR003500      Maritime (P)  Routier (R)                 FRPET
# 35  FR003620      Maritime (P)  Routier (R)                 FRPDB
# 36  FR003630      Maritime (P)  Routier (R)                 FRPJE
# 37  FR003650      Maritime (P)  Routier (R)                 FRNOU
# 38  FR003690      Maritime (P)  Routier (R)                 FRPOV
# 39  FR000040      Maritime (P)  Routier (R)                 FRPVO
# 40  None          None                                      None
# 41  FR002090      Maritime (P)  Routier (R)                 FRRCC FRRCO FRRCS
# 42  FR003920      Maritime (P)  Routier (R)                 FRURO
# 43  FR002310      Maritime (P)  Routier (R)                 FRSPK
# 44  FR004060      Maritime (P)  Routier (R)                 FRSML
# 45  FR004080      Maritime (P)  Routier (R)                 FRSNG FRSNP FRSNR
# 46  FR004250      Maritime (P)  Routier (R)                 FRSET
# 47  FR004430      Maritime (P)  Routier (R)                 FRTOA
# 48  None          None                                      None
# 49  FR006610      Maritime (P)  Routier (R)                 GPPTP
# 50  FR006340      Maritime (P)  Routier (R)                 MQFDF
# 51  FR006370      Maritime (P)  Routier (R)                 GFCAY
# 52  FR006610      Maritime (P)  Routier (R)                 GPPTP
# 53  FR006420      Maritime (P)  Routier (R)                 RELPT
# 54  FR006340      Maritime (P)  Routier (R)
# 55  FR006610      Maritime (P)  Routier (R)                 GPPTP
# 56  FR006340      Maritime (P) Routier (R)                  MQSPI
# 57  FR006800      Maritime (P) Routier (R)                  YTLON
# 58  FR006810      Maritime (P)  Routier (R)                 YTDZA
# 59  None          None                                      None
# 60  FR000860      Maritime (P) Fluvial (C)                  FRCAO
# 61  FR003410      Maritime (P) Fluvial (C)                  FRGVL
# 62  FR005500      Maritime (P) Fluvial (C)                  FRGRO
# 63  Code  bureau  Trafic                                    Code port
# 64  None          None                                      None
# 65  FR002650      Maritime (P) Fluvial (C)                  FRLIO
# 66  FR000860      Maritime (P) Fluvial (C)                  FRMAC
# 67  FR002030      Maritime (P) Fluvial (C)                  FRSAL
# 68  FR004550      Maritime (P) Fluvial (C)                  FRVAA FRVAC FRVAF
# 69  FR002650      Maritime (P) Fluvial (C)                  FRVSS
# 70  None          None                                      None
# 71  FR006370      Maritime (P)  Fluvial (C) Routier (R)     GFCAY
# 72  FR006390      Maritime (P)  Fluvial (C) Routier (R)(2)  GFSLM
# 73  FR006750      Maritime (P) Fluvial (C) Routier (R)      GFOYP

# %%
# Make all values uppercase and strip whitespace in all columns
df["point_of_entry_name"] = df.point_of_entry_name.str.upper().str.strip()
df["office_name"] = df.office_name.str.upper().str.strip()
df["office_code"] = df.office_code.str.strip()
df["traffic"] = df.traffic.str.upper().str.strip()
df["port_code"] = df.port_code.str.strip()
# Out:
#                  point_of_entry_name                    office_name  \
# 0   ►VECTEUR MARITIME (1)             None
# 1   AJACCIO                           AJACCIO
# 2   BASTIA                            BASTIA PORT
# 3   BAYONNE                           BAYONNE
# 4   BERRE L’ÉTANG (RAFFINERIE)        PORT-DE-BOUC PORT
# 5   BORDEAUX                          BASSENS
# 6   BOULOGNE-SUR-MER                  BOULOGNE
# 7   BREST                             BREST
# 8   CAEN OUISTREHAM                   CAEN
# 9   CALAIS                            BOULOGNE
# 10  CANNES                            CANNES
# 11  CHERBOURG                         CAEN
# 12  CONCARNEAU DOUARNENEZ             BREST
# 13  DIEPPE                            ROUEN PORT
# 14  DONGES RAFFINERIE                 DONGES RAFFINERIE
# 15  DUNKERQUE                         DUNKERQUE
# 16  FÉCAMP                            LE HAVRE PORT
# 17  ►VECTEUR MARITIME (1)             None
# 18  FOS-SUR-MER (RAFFINERIE)          PORT-DE-BOUC PORT
# 19  FOS PORT-SAINT-LOUIS-DU-RHÔNE     FOS PORT-SAINT-LOUIS-DU-RHÔNE
# 20  GONFREVILLE RAFFINERIE            GONFREVILLE RAFFINERIE
# 21  HONFLEUR                          LE HAVRE PORT
# 22  LA ROCHELLE PALLICE               LA ROCHELLE PALLICE
# 23  LE HAVRE                          LE HAVRE PORT
# 24  LE HAVRE ANTIFER                  LE HAVRE ANTIFER
# 25  LA MÈDE (RAFFINERIE)              PORT-DE-BOUC PORT
# 26  LAVERA (RAFFINERIE)               PORT-DE-BOUC PORT
# 27  LE TRÉPORT                        ROUEN PORT
# 28  LES SABLES D'OLONNES              LA ROCHE-SUR-YON
# 29  LORIENT                           LORIENT
# 30  MARSEILLE                         MARSEILLE PORT
# 31  MONACO                            MONACO
# 32  NANTES ATLANTIQUE                 NANTES ATLANTIQUE
# 33  NICE PORT                         NICE AÉROPORT
# 34  PETIT COURONNE RAFFINERIE         ROUEN ÉNERGIES
# 35  PORT-DE-BOUC                      PORT-DE-BOUC PORT
# 36  PORT JÉRÔME RAFFINERIE            PORT JÉRÔME RAFFINERIE
# 37  PORT-LA-NOUVELLE                  PORT-LA-NOUVELLE
# 38  PORT VENDRES                      PORT VENDRES
# 39  PORTO-VECCHIO                     AJACCIO
# 40  ►VECTEUR MARITIME (1)             None
# 41  ROCHEFORT TONNAY-CHARENTE         LA ROCHELLE PALLICE
# 42  ROUEN                             ROUEN PORT
# 43  SAINT-BRIEUC LE LÉGUÉ             SAINT-BRIEUC
# 44  SAINT-MALO                        SAINT-MALO
# 45  SAINT-NAZAIRE MONTOIR             SAINT-NAZAIRE MONTOIR
# 46  SÈTE                              SÈTE
# 47  TOULON LA SEYNE                   TOULON LA SEYNE
# 48  DOM                               None
# 49  BASSE-TERRE (GUADELOUPE)          LA POINTE JARRY
# 50  FORT-DE-FRANCE (MARTINIQUE)       FORT-DE-FRANCE PORT
# 51  KOUROU (GUYANE)                   DEGRAD DES CANNES
# 52  LA POINTE JARRY (GUADELOUPE)      LA POINTE JARRY
# 53  LE PORT (LA RÉUNION)              LE PORT
# 54  LE ROBERT (MARTINIQUE)            FORT-DE-FRANCE PORT
# 55  POINTE-À-PITRE (GUADELOUPE)       LA POINTE JARRY
# 56  SAINT-PIERRE (MARTINIQUE)         FORT-DE-FRANCE PORT
# 57  LONGONI (MAYOTTE)                 LONGONI PORT
# 58  DZAOUDZI (MAYOTTE)                PAMANDZI
# 59  ►VECTEUR FLUVIO-MARITIME          None
# 60  CHALON-SUR-SAÔNE                  CHALON-SUR-SAÔNE
# 61  GENNEVILLIERS                     GENNEVILLIERS
# 62  GRON                              AUXERRE
# 63  NOM DU  POINT D'ENTRÉE            NOM DU  BUREAU
# 64  ►VECTEUR FLUVIO-MARITIME          None
# 65  LYON PORT EDOUARD HERRIOT         LYON AÉROPORT
# 66  MÂCON                             CHALON-SUR-SAÔNE
# 67  SALAISE-SUR-SANNE                 L'ISLE D'ABEAU
# 68  VALENCE                           VALENCE
# 69  VILLEFRANCHE-SUR-SAÔNE            LYON AÉROPORT
# 70  DOM                               None
# 71  DEGRAD DES CANNES (GUYANE)        DEGRAD DES CANNES
# 72  SAINT-LAURENT DU MARONI (GUYANE)  SAINT-LAURENT DU MARONI
# 73  SAINT-GEORGES DE L'OYAPOCK        SAINT-GEORGES DE L'OYAPOCK
#
#      office_code                                   traffic          port_code
# 0   None          None                                      None
# 1   FR000040      MARITIME (P)  ROUTIER (R)                 FRAJA
# 2   FR000380      MARITIME (P)  ROUTIER (R)                 FRBIA
# 3   FR000390      MARITIME (P)  ROUTIER (R)                 FRBAY
# 4   FR003620      MARITIME (P)  ROUTIER (R)                 FRETB
# 5   FR000610      MARITIME (P)  ROUTIER (R)                 FRBAS FRBSE
# 6   FR000630      MARITIME (P)  ROUTIER (R)                 FRBOL
# 7   FR000690      MARITIME (P)  ROUTIER (R)                 FRBES
# 8   FR000720      MARITIME (P)  ROUTIER (R)                 FRCFR
# 9   FR000630      MARITIME (P)  ROUTIER (R)                 FRCQF
# 10  FR000800      MARITIME (P)  ROUTIER (R)                 FRCEQ
# 11  FR000720      MARITIME (P)  ROUTIER (R)                 FRCER
# 12  FR000690      MARITIME (P)  ROUTIER (R)                 FRCOC FRDRZ
# 13  FR003920      MARITIME (P)  ROUTIER (R)                 FRDPE
# 14  FR001200      MARITIME (P)  ROUTIER (R)                 FRDON
# 15  FR001260      MARITIME (P)  ROUTIER (R)                 FRDKK
# 16  FR002300      MARITIME (P)  ROUTIER (R)                 FRFEC
# 17  None          None                                      None
# 18  FR003620      MARITIME (P)  ROUTIER (R)                 FRFOS
# 19  FR003680      MARITIME (P)  ROUTIER (R)                 FRFOS
# 20  FR001560      MARITIME (P)  ROUTIER (R)                 FRGLO
# 21  FR002300      MARITIME (P)  ROUTIER (R)                 FRHON
# 22  FR002090      MARITIME (P)  ROUTIER (R)                 FRLRH
# 23  FR002300      MARITIME (P)  ROUTIER (R)                 FRLEH
# 24  FR002270      MARITIME (P)  ROUTIER (R)                 FRLEH
# 25  FR003620      MARITIME (P)  ROUTIER (R)                 FRLMD
# 26  FR003620      MARITIME (P)  ROUTIER (R)                 FRLAV
# 27  FR003920      MARITIME (P)  ROUTIER (R)                 FRLTR
# 28  FR006240      MARITIME (P)  ROUTIER (R)                 FRLSO
# 29  FR002600      MARITIME (P)  ROUTIER (R)                 FRLRT
# 30  FR002730      MARITIME (P)  ROUTIER (R)                 FRMRS
# 31  FR002860      MARITIME (P)  ROUTIER (R)                 MCMON
# 32  FR003030      MARITIME (P)  ROUTIER (R)                 FRNTE
# 33  FR003080      MARITIME (P)  ROUTIER (R)                 FRNCE
# 34  FR003500      MARITIME (P)  ROUTIER (R)                 FRPET
# 35  FR003620      MARITIME (P)  ROUTIER (R)                 FRPDB
# 36  FR003630      MARITIME (P)  ROUTIER (R)                 FRPJE
# 37  FR003650      MARITIME (P)  ROUTIER (R)                 FRNOU
# 38  FR003690      MARITIME (P)  ROUTIER (R)                 FRPOV
# 39  FR000040      MARITIME (P)  ROUTIER (R)                 FRPVO
# 40  None          None                                      None
# 41  FR002090      MARITIME (P)  ROUTIER (R)                 FRRCC FRRCO FRRCS
# 42  FR003920      MARITIME (P)  ROUTIER (R)                 FRURO
# 43  FR002310      MARITIME (P)  ROUTIER (R)                 FRSPK
# 44  FR004060      MARITIME (P)  ROUTIER (R)                 FRSML
# 45  FR004080      MARITIME (P)  ROUTIER (R)                 FRSNG FRSNP FRSNR
# 46  FR004250      MARITIME (P)  ROUTIER (R)                 FRSET
# 47  FR004430      MARITIME (P)  ROUTIER (R)                 FRTOA
# 48  None          None                                      None
# 49  FR006610      MARITIME (P)  ROUTIER (R)                 GPPTP
# 50  FR006340      MARITIME (P)  ROUTIER (R)                 MQFDF
# 51  FR006370      MARITIME (P)  ROUTIER (R)                 GFCAY
# 52  FR006610      MARITIME (P)  ROUTIER (R)                 GPPTP
# 53  FR006420      MARITIME (P)  ROUTIER (R)                 RELPT
# 54  FR006340      MARITIME (P)  ROUTIER (R)
# 55  FR006610      MARITIME (P)  ROUTIER (R)                 GPPTP
# 56  FR006340      MARITIME (P) ROUTIER (R)                  MQSPI
# 57  FR006800      MARITIME (P) ROUTIER (R)                  YTLON
# 58  FR006810      MARITIME (P)  ROUTIER (R)                 YTDZA
# 59  None          None                                      None
# 60  FR000860      MARITIME (P) FLUVIAL (C)                  FRCAO
# 61  FR003410      MARITIME (P) FLUVIAL (C)                  FRGVL
# 62  FR005500      MARITIME (P) FLUVIAL (C)                  FRGRO
# 63  Code  bureau  TRAFIC                                    Code port
# 64  None          None                                      None
# 65  FR002650      MARITIME (P) FLUVIAL (C)                  FRLIO
# 66  FR000860      MARITIME (P) FLUVIAL (C)                  FRMAC
# 67  FR002030      MARITIME (P) FLUVIAL (C)                  FRSAL
# 68  FR004550      MARITIME (P) FLUVIAL (C)                  FRVAA FRVAC FRVAF
# 69  FR002650      MARITIME (P) FLUVIAL (C)                  FRVSS
# 70  None          None                                      None
# 71  FR006370      MARITIME (P)  FLUVIAL (C) ROUTIER (R)     GFCAY
# 72  FR006390      MARITIME (P)  FLUVIAL (C) ROUTIER (R)(2)  GFSLM
# 73  FR006750      MARITIME (P) FLUVIAL (C) ROUTIER (R)      GFOYP

# %%
# Remove all French accents from strings in columns "point_of_entry_name", "office_name" and "traffic"
df["point_of_entry_name"] = df.point_of_entry_name.str.normalize("NFKD") \
                                                  .str.encode("ascii", errors="ignore").str.decode("utf-8")
df["office_name"] = df.office_name.str.normalize("NFKD").str.encode("ascii", errors="ignore").str.decode("utf-8")
df["traffic"] = df.traffic.str.normalize("NFKD").str.encode("ascii", errors="ignore").str.decode("utf-8")
# Out:
#                  point_of_entry_name                    office_name  \
# 0   VECTEUR MARITIME (1)              None
# 1   AJACCIO                           AJACCIO
# 2   BASTIA                            BASTIA PORT
# 3   BAYONNE                           BAYONNE
# 4   BERRE LETANG (RAFFINERIE)         PORT-DE-BOUC PORT
# 5   BORDEAUX                          BASSENS
# 6   BOULOGNE-SUR-MER                  BOULOGNE
# 7   BREST                             BREST
# 8   CAEN OUISTREHAM                   CAEN
# 9   CALAIS                            BOULOGNE
# 10  CANNES                            CANNES
# 11  CHERBOURG                         CAEN
# 12  CONCARNEAU DOUARNENEZ             BREST
# 13  DIEPPE                            ROUEN PORT
# 14  DONGES RAFFINERIE                 DONGES RAFFINERIE
# 15  DUNKERQUE                         DUNKERQUE
# 16  FECAMP                            LE HAVRE PORT
# 17  VECTEUR MARITIME (1)              None
# 18  FOS-SUR-MER (RAFFINERIE)          PORT-DE-BOUC PORT
# 19  FOS PORT-SAINT-LOUIS-DU-RHONE     FOS PORT-SAINT-LOUIS-DU-RHONE
# 20  GONFREVILLE RAFFINERIE            GONFREVILLE RAFFINERIE
# 21  HONFLEUR                          LE HAVRE PORT
# 22  LA ROCHELLE PALLICE               LA ROCHELLE PALLICE
# 23  LE HAVRE                          LE HAVRE PORT
# 24  LE HAVRE ANTIFER                  LE HAVRE ANTIFER
# 25  LA MEDE (RAFFINERIE)              PORT-DE-BOUC PORT
# 26  LAVERA (RAFFINERIE)               PORT-DE-BOUC PORT
# 27  LE TREPORT                        ROUEN PORT
# 28  LES SABLES D'OLONNES              LA ROCHE-SUR-YON
# 29  LORIENT                           LORIENT
# 30  MARSEILLE                         MARSEILLE PORT
# 31  MONACO                            MONACO
# 32  NANTES ATLANTIQUE                 NANTES ATLANTIQUE
# 33  NICE PORT                         NICE AEROPORT
# 34  PETIT COURONNE RAFFINERIE         ROUEN ENERGIES
# 35  PORT-DE-BOUC                      PORT-DE-BOUC PORT
# 36  PORT JEROME RAFFINERIE            PORT JEROME RAFFINERIE
# 37  PORT-LA-NOUVELLE                  PORT-LA-NOUVELLE
# 38  PORT VENDRES                      PORT VENDRES
# 39  PORTO-VECCHIO                     AJACCIO
# 40  VECTEUR MARITIME (1)              None
# 41  ROCHEFORT TONNAY-CHARENTE         LA ROCHELLE PALLICE
# 42  ROUEN                             ROUEN PORT
# 43  SAINT-BRIEUC LE LEGUE             SAINT-BRIEUC
# 44  SAINT-MALO                        SAINT-MALO
# 45  SAINT-NAZAIRE MONTOIR             SAINT-NAZAIRE MONTOIR
# 46  SETE                              SETE
# 47  TOULON LA SEYNE                   TOULON LA SEYNE
# 48  DOM                               None
# 49  BASSE-TERRE (GUADELOUPE)          LA POINTE JARRY
# 50  FORT-DE-FRANCE (MARTINIQUE)       FORT-DE-FRANCE PORT
# 51  KOUROU (GUYANE)                   DEGRAD DES CANNES
# 52  LA POINTE JARRY (GUADELOUPE)      LA POINTE JARRY
# 53  LE PORT (LA REUNION)              LE PORT
# 54  LE ROBERT (MARTINIQUE)            FORT-DE-FRANCE PORT
# 55  POINTE-A-PITRE (GUADELOUPE)       LA POINTE JARRY
# 56  SAINT-PIERRE (MARTINIQUE)         FORT-DE-FRANCE PORT
# 57  LONGONI (MAYOTTE)                 LONGONI PORT
# 58  DZAOUDZI (MAYOTTE)                PAMANDZI
# 59  VECTEUR FLUVIO-MARITIME           None
# 60  CHALON-SUR-SAONE                  CHALON-SUR-SAONE
# 61  GENNEVILLIERS                     GENNEVILLIERS
# 62  GRON                              AUXERRE
# 63  NOM DU  POINT D'ENTREE            NOM DU  BUREAU
# 64  VECTEUR FLUVIO-MARITIME           None
# 65  LYON PORT EDOUARD HERRIOT         LYON AEROPORT
# 66  MACON                             CHALON-SUR-SAONE
# 67  SALAISE-SUR-SANNE                 L'ISLE D'ABEAU
# 68  VALENCE                           VALENCE
# 69  VILLEFRANCHE-SUR-SAONE            LYON AEROPORT
# 70  DOM                               None
# 71  DEGRAD DES CANNES (GUYANE)        DEGRAD DES CANNES
# 72  SAINT-LAURENT DU MARONI (GUYANE)  SAINT-LAURENT DU MARONI
# 73  SAINT-GEORGES DE L'OYAPOCK        SAINT-GEORGES DE L'OYAPOCK
#
#      office_code                                   traffic          port_code
# 0   None          None                                      None
# 1   FR000040      MARITIME (P)  ROUTIER (R)                 FRAJA
# 2   FR000380      MARITIME (P)  ROUTIER (R)                 FRBIA
# 3   FR000390      MARITIME (P)  ROUTIER (R)                 FRBAY
# 4   FR003620      MARITIME (P)  ROUTIER (R)                 FRETB
# 5   FR000610      MARITIME (P)  ROUTIER (R)                 FRBAS FRBSE
# 6   FR000630      MARITIME (P)  ROUTIER (R)                 FRBOL
# 7   FR000690      MARITIME (P)  ROUTIER (R)                 FRBES
# 8   FR000720      MARITIME (P)  ROUTIER (R)                 FRCFR
# 9   FR000630      MARITIME (P)  ROUTIER (R)                 FRCQF
# 10  FR000800      MARITIME (P)  ROUTIER (R)                 FRCEQ
# 11  FR000720      MARITIME (P)  ROUTIER (R)                 FRCER
# 12  FR000690      MARITIME (P)  ROUTIER (R)                 FRCOC FRDRZ
# 13  FR003920      MARITIME (P)  ROUTIER (R)                 FRDPE
# 14  FR001200      MARITIME (P)  ROUTIER (R)                 FRDON
# 15  FR001260      MARITIME (P)  ROUTIER (R)                 FRDKK
# 16  FR002300      MARITIME (P)  ROUTIER (R)                 FRFEC
# 17  None          None                                      None
# 18  FR003620      MARITIME (P)  ROUTIER (R)                 FRFOS
# 19  FR003680      MARITIME (P)  ROUTIER (R)                 FRFOS
# 20  FR001560      MARITIME (P)  ROUTIER (R)                 FRGLO
# 21  FR002300      MARITIME (P)  ROUTIER (R)                 FRHON
# 22  FR002090      MARITIME (P)  ROUTIER (R)                 FRLRH
# 23  FR002300      MARITIME (P)  ROUTIER (R)                 FRLEH
# 24  FR002270      MARITIME (P)  ROUTIER (R)                 FRLEH
# 25  FR003620      MARITIME (P)  ROUTIER (R)                 FRLMD
# 26  FR003620      MARITIME (P)  ROUTIER (R)                 FRLAV
# 27  FR003920      MARITIME (P)  ROUTIER (R)                 FRLTR
# 28  FR006240      MARITIME (P)  ROUTIER (R)                 FRLSO
# 29  FR002600      MARITIME (P)  ROUTIER (R)                 FRLRT
# 30  FR002730      MARITIME (P)  ROUTIER (R)                 FRMRS
# 31  FR002860      MARITIME (P)  ROUTIER (R)                 MCMON
# 32  FR003030      MARITIME (P)  ROUTIER (R)                 FRNTE
# 33  FR003080      MARITIME (P)  ROUTIER (R)                 FRNCE
# 34  FR003500      MARITIME (P)  ROUTIER (R)                 FRPET
# 35  FR003620      MARITIME (P)  ROUTIER (R)                 FRPDB
# 36  FR003630      MARITIME (P)  ROUTIER (R)                 FRPJE
# 37  FR003650      MARITIME (P)  ROUTIER (R)                 FRNOU
# 38  FR003690      MARITIME (P)  ROUTIER (R)                 FRPOV
# 39  FR000040      MARITIME (P)  ROUTIER (R)                 FRPVO
# 40  None          None                                      None
# 41  FR002090      MARITIME (P)  ROUTIER (R)                 FRRCC FRRCO FRRCS
# 42  FR003920      MARITIME (P)  ROUTIER (R)                 FRURO
# 43  FR002310      MARITIME (P)  ROUTIER (R)                 FRSPK
# 44  FR004060      MARITIME (P)  ROUTIER (R)                 FRSML
# 45  FR004080      MARITIME (P)  ROUTIER (R)                 FRSNG FRSNP FRSNR
# 46  FR004250      MARITIME (P)  ROUTIER (R)                 FRSET
# 47  FR004430      MARITIME (P)  ROUTIER (R)                 FRTOA
# 48  None          None                                      None
# 49  FR006610      MARITIME (P)  ROUTIER (R)                 GPPTP
# 50  FR006340      MARITIME (P)  ROUTIER (R)                 MQFDF
# 51  FR006370      MARITIME (P)  ROUTIER (R)                 GFCAY
# 52  FR006610      MARITIME (P)  ROUTIER (R)                 GPPTP
# 53  FR006420      MARITIME (P)  ROUTIER (R)                 RELPT
# 54  FR006340      MARITIME (P)  ROUTIER (R)
# 55  FR006610      MARITIME (P)  ROUTIER (R)                 GPPTP
# 56  FR006340      MARITIME (P) ROUTIER (R)                  MQSPI
# 57  FR006800      MARITIME (P) ROUTIER (R)                  YTLON
# 58  FR006810      MARITIME (P)  ROUTIER (R)                 YTDZA
# 59  None          None                                      None
# 60  FR000860      MARITIME (P) FLUVIAL (C)                  FRCAO
# 61  FR003410      MARITIME (P) FLUVIAL (C)                  FRGVL
# 62  FR005500      MARITIME (P) FLUVIAL (C)                  FRGRO
# 63  Code  bureau  TRAFIC                                    Code port
# 64  None          None                                      None
# 65  FR002650      MARITIME (P) FLUVIAL (C)                  FRLIO
# 66  FR000860      MARITIME (P) FLUVIAL (C)                  FRMAC
# 67  FR002030      MARITIME (P) FLUVIAL (C)                  FRSAL
# 68  FR004550      MARITIME (P) FLUVIAL (C)                  FRVAA FRVAC FRVAF
# 69  FR002650      MARITIME (P) FLUVIAL (C)                  FRVSS
# 70  None          None                                      None
# 71  FR006370      MARITIME (P)  FLUVIAL (C) ROUTIER (R)     GFCAY
# 72  FR006390      MARITIME (P)  FLUVIAL (C) ROUTIER (R)(2)  GFSLM
# 73  FR006750      MARITIME (P) FLUVIAL (C) ROUTIER (R)      GFOYP

# %%
# Select indexes where vector values are equals to "Vecteur maritime"
# Assign "SEA PORT" value to entries in new column "port_type"
df.loc[0:58, "port_type"] = "SEA PORT"
# Out:
#                  point_of_entry_name                    office_name  \
# 0   VECTEUR MARITIME (1)              None
# 1   AJACCIO                           AJACCIO
# 2   BASTIA                            BASTIA PORT
# 3   BAYONNE                           BAYONNE
# 4   BERRE LETANG (RAFFINERIE)         PORT-DE-BOUC PORT
# 5   BORDEAUX                          BASSENS
# 6   BOULOGNE-SUR-MER                  BOULOGNE
# 7   BREST                             BREST
# 8   CAEN OUISTREHAM                   CAEN
# 9   CALAIS                            BOULOGNE
# 10  CANNES                            CANNES
# 11  CHERBOURG                         CAEN
# 12  CONCARNEAU DOUARNENEZ             BREST
# 13  DIEPPE                            ROUEN PORT
# 14  DONGES RAFFINERIE                 DONGES RAFFINERIE
# 15  DUNKERQUE                         DUNKERQUE
# 16  FECAMP                            LE HAVRE PORT
# 17  VECTEUR MARITIME (1)              None
# 18  FOS-SUR-MER (RAFFINERIE)          PORT-DE-BOUC PORT
# 19  FOS PORT-SAINT-LOUIS-DU-RHONE     FOS PORT-SAINT-LOUIS-DU-RHONE
# 20  GONFREVILLE RAFFINERIE            GONFREVILLE RAFFINERIE
# 21  HONFLEUR                          LE HAVRE PORT
# 22  LA ROCHELLE PALLICE               LA ROCHELLE PALLICE
# 23  LE HAVRE                          LE HAVRE PORT
# 24  LE HAVRE ANTIFER                  LE HAVRE ANTIFER
# 25  LA MEDE (RAFFINERIE)              PORT-DE-BOUC PORT
# 26  LAVERA (RAFFINERIE)               PORT-DE-BOUC PORT
# 27  LE TREPORT                        ROUEN PORT
# 28  LES SABLES D'OLONNES              LA ROCHE-SUR-YON
# 29  LORIENT                           LORIENT
# 30  MARSEILLE                         MARSEILLE PORT
# 31  MONACO                            MONACO
# 32  NANTES ATLANTIQUE                 NANTES ATLANTIQUE
# 33  NICE PORT                         NICE AEROPORT
# 34  PETIT COURONNE RAFFINERIE         ROUEN ENERGIES
# 35  PORT-DE-BOUC                      PORT-DE-BOUC PORT
# 36  PORT JEROME RAFFINERIE            PORT JEROME RAFFINERIE
# 37  PORT-LA-NOUVELLE                  PORT-LA-NOUVELLE
# 38  PORT VENDRES                      PORT VENDRES
# 39  PORTO-VECCHIO                     AJACCIO
# 40  VECTEUR MARITIME (1)              None
# 41  ROCHEFORT TONNAY-CHARENTE         LA ROCHELLE PALLICE
# 42  ROUEN                             ROUEN PORT
# 43  SAINT-BRIEUC LE LEGUE             SAINT-BRIEUC
# 44  SAINT-MALO                        SAINT-MALO
# 45  SAINT-NAZAIRE MONTOIR             SAINT-NAZAIRE MONTOIR
# 46  SETE                              SETE
# 47  TOULON LA SEYNE                   TOULON LA SEYNE
# 48  DOM                               None
# 49  BASSE-TERRE (GUADELOUPE)          LA POINTE JARRY
# 50  FORT-DE-FRANCE (MARTINIQUE)       FORT-DE-FRANCE PORT
# 51  KOUROU (GUYANE)                   DEGRAD DES CANNES
# 52  LA POINTE JARRY (GUADELOUPE)      LA POINTE JARRY
# 53  LE PORT (LA REUNION)              LE PORT
# 54  LE ROBERT (MARTINIQUE)            FORT-DE-FRANCE PORT
# 55  POINTE-A-PITRE (GUADELOUPE)       LA POINTE JARRY
# 56  SAINT-PIERRE (MARTINIQUE)         FORT-DE-FRANCE PORT
# 57  LONGONI (MAYOTTE)                 LONGONI PORT
# 58  DZAOUDZI (MAYOTTE)                PAMANDZI
# 59  VECTEUR FLUVIO-MARITIME           None
# 60  CHALON-SUR-SAONE                  CHALON-SUR-SAONE
# 61  GENNEVILLIERS                     GENNEVILLIERS
# 62  GRON                              AUXERRE
# 63  NOM DU  POINT D'ENTREE            NOM DU  BUREAU
# 64  VECTEUR FLUVIO-MARITIME           None
# 65  LYON PORT EDOUARD HERRIOT         LYON AEROPORT
# 66  MACON                             CHALON-SUR-SAONE
# 67  SALAISE-SUR-SANNE                 L'ISLE D'ABEAU
# 68  VALENCE                           VALENCE
# 69  VILLEFRANCHE-SUR-SAONE            LYON AEROPORT
# 70  DOM                               None
# 71  DEGRAD DES CANNES (GUYANE)        DEGRAD DES CANNES
# 72  SAINT-LAURENT DU MARONI (GUYANE)  SAINT-LAURENT DU MARONI
# 73  SAINT-GEORGES DE L'OYAPOCK        SAINT-GEORGES DE L'OYAPOCK
#
#      office_code                                   traffic          port_code  \
# 0   None          None                                      None
# 1   FR000040      MARITIME (P)  ROUTIER (R)                 FRAJA
# 2   FR000380      MARITIME (P)  ROUTIER (R)                 FRBIA
# 3   FR000390      MARITIME (P)  ROUTIER (R)                 FRBAY
# 4   FR003620      MARITIME (P)  ROUTIER (R)                 FRETB
# 5   FR000610      MARITIME (P)  ROUTIER (R)                 FRBAS FRBSE
# 6   FR000630      MARITIME (P)  ROUTIER (R)                 FRBOL
# 7   FR000690      MARITIME (P)  ROUTIER (R)                 FRBES
# 8   FR000720      MARITIME (P)  ROUTIER (R)                 FRCFR
# 9   FR000630      MARITIME (P)  ROUTIER (R)                 FRCQF
# 10  FR000800      MARITIME (P)  ROUTIER (R)                 FRCEQ
# 11  FR000720      MARITIME (P)  ROUTIER (R)                 FRCER
# 12  FR000690      MARITIME (P)  ROUTIER (R)                 FRCOC FRDRZ
# 13  FR003920      MARITIME (P)  ROUTIER (R)                 FRDPE
# 14  FR001200      MARITIME (P)  ROUTIER (R)                 FRDON
# 15  FR001260      MARITIME (P)  ROUTIER (R)                 FRDKK
# 16  FR002300      MARITIME (P)  ROUTIER (R)                 FRFEC
# 17  None          None                                      None
# 18  FR003620      MARITIME (P)  ROUTIER (R)                 FRFOS
# 19  FR003680      MARITIME (P)  ROUTIER (R)                 FRFOS
# 20  FR001560      MARITIME (P)  ROUTIER (R)                 FRGLO
# 21  FR002300      MARITIME (P)  ROUTIER (R)                 FRHON
# 22  FR002090      MARITIME (P)  ROUTIER (R)                 FRLRH
# 23  FR002300      MARITIME (P)  ROUTIER (R)                 FRLEH
# 24  FR002270      MARITIME (P)  ROUTIER (R)                 FRLEH
# 25  FR003620      MARITIME (P)  ROUTIER (R)                 FRLMD
# 26  FR003620      MARITIME (P)  ROUTIER (R)                 FRLAV
# 27  FR003920      MARITIME (P)  ROUTIER (R)                 FRLTR
# 28  FR006240      MARITIME (P)  ROUTIER (R)                 FRLSO
# 29  FR002600      MARITIME (P)  ROUTIER (R)                 FRLRT
# 30  FR002730      MARITIME (P)  ROUTIER (R)                 FRMRS
# 31  FR002860      MARITIME (P)  ROUTIER (R)                 MCMON
# 32  FR003030      MARITIME (P)  ROUTIER (R)                 FRNTE
# 33  FR003080      MARITIME (P)  ROUTIER (R)                 FRNCE
# 34  FR003500      MARITIME (P)  ROUTIER (R)                 FRPET
# 35  FR003620      MARITIME (P)  ROUTIER (R)                 FRPDB
# 36  FR003630      MARITIME (P)  ROUTIER (R)                 FRPJE
# 37  FR003650      MARITIME (P)  ROUTIER (R)                 FRNOU
# 38  FR003690      MARITIME (P)  ROUTIER (R)                 FRPOV
# 39  FR000040      MARITIME (P)  ROUTIER (R)                 FRPVO
# 40  None          None                                      None
# 41  FR002090      MARITIME (P)  ROUTIER (R)                 FRRCC FRRCO FRRCS
# 42  FR003920      MARITIME (P)  ROUTIER (R)                 FRURO
# 43  FR002310      MARITIME (P)  ROUTIER (R)                 FRSPK
# 44  FR004060      MARITIME (P)  ROUTIER (R)                 FRSML
# 45  FR004080      MARITIME (P)  ROUTIER (R)                 FRSNG FRSNP FRSNR
# 46  FR004250      MARITIME (P)  ROUTIER (R)                 FRSET
# 47  FR004430      MARITIME (P)  ROUTIER (R)                 FRTOA
# 48  None          None                                      None
# 49  FR006610      MARITIME (P)  ROUTIER (R)                 GPPTP
# 50  FR006340      MARITIME (P)  ROUTIER (R)                 MQFDF
# 51  FR006370      MARITIME (P)  ROUTIER (R)                 GFCAY
# 52  FR006610      MARITIME (P)  ROUTIER (R)                 GPPTP
# 53  FR006420      MARITIME (P)  ROUTIER (R)                 RELPT
# 54  FR006340      MARITIME (P)  ROUTIER (R)
# 55  FR006610      MARITIME (P)  ROUTIER (R)                 GPPTP
# 56  FR006340      MARITIME (P) ROUTIER (R)                  MQSPI
# 57  FR006800      MARITIME (P) ROUTIER (R)                  YTLON
# 58  FR006810      MARITIME (P)  ROUTIER (R)                 YTDZA
# 59  None          None                                      None
# 60  FR000860      MARITIME (P) FLUVIAL (C)                  FRCAO
# 61  FR003410      MARITIME (P) FLUVIAL (C)                  FRGVL
# 62  FR005500      MARITIME (P) FLUVIAL (C)                  FRGRO
# 63  Code  bureau  TRAFIC                                    Code port
# 64  None          None                                      None
# 65  FR002650      MARITIME (P) FLUVIAL (C)                  FRLIO
# 66  FR000860      MARITIME (P) FLUVIAL (C)                  FRMAC
# 67  FR002030      MARITIME (P) FLUVIAL (C)                  FRSAL
# 68  FR004550      MARITIME (P) FLUVIAL (C)                  FRVAA FRVAC FRVAF
# 69  FR002650      MARITIME (P) FLUVIAL (C)                  FRVSS
# 70  None          None                                      None
# 71  FR006370      MARITIME (P)  FLUVIAL (C) ROUTIER (R)     GFCAY
# 72  FR006390      MARITIME (P)  FLUVIAL (C) ROUTIER (R)(2)  GFSLM
# 73  FR006750      MARITIME (P) FLUVIAL (C) ROUTIER (R)      GFOYP
#
#    port_type
# 0   SEA PORT
# 1   SEA PORT
# 2   SEA PORT
# 3   SEA PORT
# 4   SEA PORT
# 5   SEA PORT
# 6   SEA PORT
# 7   SEA PORT
# 8   SEA PORT
# 9   SEA PORT
# 10  SEA PORT
# 11  SEA PORT
# 12  SEA PORT
# 13  SEA PORT
# 14  SEA PORT
# 15  SEA PORT
# 16  SEA PORT
# 17  SEA PORT
# 18  SEA PORT
# 19  SEA PORT
# 20  SEA PORT
# 21  SEA PORT
# 22  SEA PORT
# 23  SEA PORT
# 24  SEA PORT
# 25  SEA PORT
# 26  SEA PORT
# 27  SEA PORT
# 28  SEA PORT
# 29  SEA PORT
# 30  SEA PORT
# 31  SEA PORT
# 32  SEA PORT
# 33  SEA PORT
# 34  SEA PORT
# 35  SEA PORT
# 36  SEA PORT
# 37  SEA PORT
# 38  SEA PORT
# 39  SEA PORT
# 40  SEA PORT
# 41  SEA PORT
# 42  SEA PORT
# 43  SEA PORT
# 44  SEA PORT
# 45  SEA PORT
# 46  SEA PORT
# 47  SEA PORT
# 48  SEA PORT
# 49  SEA PORT
# 50  SEA PORT
# 51  SEA PORT
# 52  SEA PORT
# 53  SEA PORT
# 54  SEA PORT
# 55  SEA PORT
# 56  SEA PORT
# 57  SEA PORT
# 58  SEA PORT
# 59  NaN
# 60  NaN
# 61  NaN
# 62  NaN
# 63  NaN
# 64  NaN
# 65  NaN
# 66  NaN
# 67  NaN
# 68  NaN
# 69  NaN
# 70  NaN
# 71  NaN
# 72  NaN
# 73  NaN

# %%
# Select indexes where vector values are equals to "Vecteur fluvio-maritime"
# Assign "SEA AND RIVER PORT" value to entries in column "port_type"
df.loc[59:74, "port_type"] = "SEA AND RIVER PORT"
# Out:
#                  point_of_entry_name                    office_name  \
# 0   VECTEUR MARITIME (1)              None
# 1   AJACCIO                           AJACCIO
# 2   BASTIA                            BASTIA PORT
# 3   BAYONNE                           BAYONNE
# 4   BERRE LETANG (RAFFINERIE)         PORT-DE-BOUC PORT
# 5   BORDEAUX                          BASSENS
# 6   BOULOGNE-SUR-MER                  BOULOGNE
# 7   BREST                             BREST
# 8   CAEN OUISTREHAM                   CAEN
# 9   CALAIS                            BOULOGNE
# 10  CANNES                            CANNES
# 11  CHERBOURG                         CAEN
# 12  CONCARNEAU DOUARNENEZ             BREST
# 13  DIEPPE                            ROUEN PORT
# 14  DONGES RAFFINERIE                 DONGES RAFFINERIE
# 15  DUNKERQUE                         DUNKERQUE
# 16  FECAMP                            LE HAVRE PORT
# 17  VECTEUR MARITIME (1)              None
# 18  FOS-SUR-MER (RAFFINERIE)          PORT-DE-BOUC PORT
# 19  FOS PORT-SAINT-LOUIS-DU-RHONE     FOS PORT-SAINT-LOUIS-DU-RHONE
# 20  GONFREVILLE RAFFINERIE            GONFREVILLE RAFFINERIE
# 21  HONFLEUR                          LE HAVRE PORT
# 22  LA ROCHELLE PALLICE               LA ROCHELLE PALLICE
# 23  LE HAVRE                          LE HAVRE PORT
# 24  LE HAVRE ANTIFER                  LE HAVRE ANTIFER
# 25  LA MEDE (RAFFINERIE)              PORT-DE-BOUC PORT
# 26  LAVERA (RAFFINERIE)               PORT-DE-BOUC PORT
# 27  LE TREPORT                        ROUEN PORT
# 28  LES SABLES D'OLONNES              LA ROCHE-SUR-YON
# 29  LORIENT                           LORIENT
# 30  MARSEILLE                         MARSEILLE PORT
# 31  MONACO                            MONACO
# 32  NANTES ATLANTIQUE                 NANTES ATLANTIQUE
# 33  NICE PORT                         NICE AEROPORT
# 34  PETIT COURONNE RAFFINERIE         ROUEN ENERGIES
# 35  PORT-DE-BOUC                      PORT-DE-BOUC PORT
# 36  PORT JEROME RAFFINERIE            PORT JEROME RAFFINERIE
# 37  PORT-LA-NOUVELLE                  PORT-LA-NOUVELLE
# 38  PORT VENDRES                      PORT VENDRES
# 39  PORTO-VECCHIO                     AJACCIO
# 40  VECTEUR MARITIME (1)              None
# 41  ROCHEFORT TONNAY-CHARENTE         LA ROCHELLE PALLICE
# 42  ROUEN                             ROUEN PORT
# 43  SAINT-BRIEUC LE LEGUE             SAINT-BRIEUC
# 44  SAINT-MALO                        SAINT-MALO
# 45  SAINT-NAZAIRE MONTOIR             SAINT-NAZAIRE MONTOIR
# 46  SETE                              SETE
# 47  TOULON LA SEYNE                   TOULON LA SEYNE
# 48  DOM                               None
# 49  BASSE-TERRE (GUADELOUPE)          LA POINTE JARRY
# 50  FORT-DE-FRANCE (MARTINIQUE)       FORT-DE-FRANCE PORT
# 51  KOUROU (GUYANE)                   DEGRAD DES CANNES
# 52  LA POINTE JARRY (GUADELOUPE)      LA POINTE JARRY
# 53  LE PORT (LA REUNION)              LE PORT
# 54  LE ROBERT (MARTINIQUE)            FORT-DE-FRANCE PORT
# 55  POINTE-A-PITRE (GUADELOUPE)       LA POINTE JARRY
# 56  SAINT-PIERRE (MARTINIQUE)         FORT-DE-FRANCE PORT
# 57  LONGONI (MAYOTTE)                 LONGONI PORT
# 58  DZAOUDZI (MAYOTTE)                PAMANDZI
# 59  VECTEUR FLUVIO-MARITIME           None
# 60  CHALON-SUR-SAONE                  CHALON-SUR-SAONE
# 61  GENNEVILLIERS                     GENNEVILLIERS
# 62  GRON                              AUXERRE
# 63  NOM DU  POINT D'ENTREE            NOM DU  BUREAU
# 64  VECTEUR FLUVIO-MARITIME           None
# 65  LYON PORT EDOUARD HERRIOT         LYON AEROPORT
# 66  MACON                             CHALON-SUR-SAONE
# 67  SALAISE-SUR-SANNE                 L'ISLE D'ABEAU
# 68  VALENCE                           VALENCE
# 69  VILLEFRANCHE-SUR-SAONE            LYON AEROPORT
# 70  DOM                               None
# 71  DEGRAD DES CANNES (GUYANE)        DEGRAD DES CANNES
# 72  SAINT-LAURENT DU MARONI (GUYANE)  SAINT-LAURENT DU MARONI
# 73  SAINT-GEORGES DE L'OYAPOCK        SAINT-GEORGES DE L'OYAPOCK
#
#      office_code                                   traffic          port_code  \
# 0   None          None                                      None
# 1   FR000040      MARITIME (P)  ROUTIER (R)                 FRAJA
# 2   FR000380      MARITIME (P)  ROUTIER (R)                 FRBIA
# 3   FR000390      MARITIME (P)  ROUTIER (R)                 FRBAY
# 4   FR003620      MARITIME (P)  ROUTIER (R)                 FRETB
# 5   FR000610      MARITIME (P)  ROUTIER (R)                 FRBAS FRBSE
# 6   FR000630      MARITIME (P)  ROUTIER (R)                 FRBOL
# 7   FR000690      MARITIME (P)  ROUTIER (R)                 FRBES
# 8   FR000720      MARITIME (P)  ROUTIER (R)                 FRCFR
# 9   FR000630      MARITIME (P)  ROUTIER (R)                 FRCQF
# 10  FR000800      MARITIME (P)  ROUTIER (R)                 FRCEQ
# 11  FR000720      MARITIME (P)  ROUTIER (R)                 FRCER
# 12  FR000690      MARITIME (P)  ROUTIER (R)                 FRCOC FRDRZ
# 13  FR003920      MARITIME (P)  ROUTIER (R)                 FRDPE
# 14  FR001200      MARITIME (P)  ROUTIER (R)                 FRDON
# 15  FR001260      MARITIME (P)  ROUTIER (R)                 FRDKK
# 16  FR002300      MARITIME (P)  ROUTIER (R)                 FRFEC
# 17  None          None                                      None
# 18  FR003620      MARITIME (P)  ROUTIER (R)                 FRFOS
# 19  FR003680      MARITIME (P)  ROUTIER (R)                 FRFOS
# 20  FR001560      MARITIME (P)  ROUTIER (R)                 FRGLO
# 21  FR002300      MARITIME (P)  ROUTIER (R)                 FRHON
# 22  FR002090      MARITIME (P)  ROUTIER (R)                 FRLRH
# 23  FR002300      MARITIME (P)  ROUTIER (R)                 FRLEH
# 24  FR002270      MARITIME (P)  ROUTIER (R)                 FRLEH
# 25  FR003620      MARITIME (P)  ROUTIER (R)                 FRLMD
# 26  FR003620      MARITIME (P)  ROUTIER (R)                 FRLAV
# 27  FR003920      MARITIME (P)  ROUTIER (R)                 FRLTR
# 28  FR006240      MARITIME (P)  ROUTIER (R)                 FRLSO
# 29  FR002600      MARITIME (P)  ROUTIER (R)                 FRLRT
# 30  FR002730      MARITIME (P)  ROUTIER (R)                 FRMRS
# 31  FR002860      MARITIME (P)  ROUTIER (R)                 MCMON
# 32  FR003030      MARITIME (P)  ROUTIER (R)                 FRNTE
# 33  FR003080      MARITIME (P)  ROUTIER (R)                 FRNCE
# 34  FR003500      MARITIME (P)  ROUTIER (R)                 FRPET
# 35  FR003620      MARITIME (P)  ROUTIER (R)                 FRPDB
# 36  FR003630      MARITIME (P)  ROUTIER (R)                 FRPJE
# 37  FR003650      MARITIME (P)  ROUTIER (R)                 FRNOU
# 38  FR003690      MARITIME (P)  ROUTIER (R)                 FRPOV
# 39  FR000040      MARITIME (P)  ROUTIER (R)                 FRPVO
# 40  None          None                                      None
# 41  FR002090      MARITIME (P)  ROUTIER (R)                 FRRCC FRRCO FRRCS
# 42  FR003920      MARITIME (P)  ROUTIER (R)                 FRURO
# 43  FR002310      MARITIME (P)  ROUTIER (R)                 FRSPK
# 44  FR004060      MARITIME (P)  ROUTIER (R)                 FRSML
# 45  FR004080      MARITIME (P)  ROUTIER (R)                 FRSNG FRSNP FRSNR
# 46  FR004250      MARITIME (P)  ROUTIER (R)                 FRSET
# 47  FR004430      MARITIME (P)  ROUTIER (R)                 FRTOA
# 48  None          None                                      None
# 49  FR006610      MARITIME (P)  ROUTIER (R)                 GPPTP
# 50  FR006340      MARITIME (P)  ROUTIER (R)                 MQFDF
# 51  FR006370      MARITIME (P)  ROUTIER (R)                 GFCAY
# 52  FR006610      MARITIME (P)  ROUTIER (R)                 GPPTP
# 53  FR006420      MARITIME (P)  ROUTIER (R)                 RELPT
# 54  FR006340      MARITIME (P)  ROUTIER (R)
# 55  FR006610      MARITIME (P)  ROUTIER (R)                 GPPTP
# 56  FR006340      MARITIME (P) ROUTIER (R)                  MQSPI
# 57  FR006800      MARITIME (P) ROUTIER (R)                  YTLON
# 58  FR006810      MARITIME (P)  ROUTIER (R)                 YTDZA
# 59  None          None                                      None
# 60  FR000860      MARITIME (P) FLUVIAL (C)                  FRCAO
# 61  FR003410      MARITIME (P) FLUVIAL (C)                  FRGVL
# 62  FR005500      MARITIME (P) FLUVIAL (C)                  FRGRO
# 63  Code  bureau  TRAFIC                                    Code port
# 64  None          None                                      None
# 65  FR002650      MARITIME (P) FLUVIAL (C)                  FRLIO
# 66  FR000860      MARITIME (P) FLUVIAL (C)                  FRMAC
# 67  FR002030      MARITIME (P) FLUVIAL (C)                  FRSAL
# 68  FR004550      MARITIME (P) FLUVIAL (C)                  FRVAA FRVAC FRVAF
# 69  FR002650      MARITIME (P) FLUVIAL (C)                  FRVSS
# 70  None          None                                      None
# 71  FR006370      MARITIME (P)  FLUVIAL (C) ROUTIER (R)     GFCAY
# 72  FR006390      MARITIME (P)  FLUVIAL (C) ROUTIER (R)(2)  GFSLM
# 73  FR006750      MARITIME (P) FLUVIAL (C) ROUTIER (R)      GFOYP
#
#              port_type
# 0   SEA PORT
# 1   SEA PORT
# 2   SEA PORT
# 3   SEA PORT
# 4   SEA PORT
# 5   SEA PORT
# 6   SEA PORT
# 7   SEA PORT
# 8   SEA PORT
# 9   SEA PORT
# 10  SEA PORT
# 11  SEA PORT
# 12  SEA PORT
# 13  SEA PORT
# 14  SEA PORT
# 15  SEA PORT
# 16  SEA PORT
# 17  SEA PORT
# 18  SEA PORT
# 19  SEA PORT
# 20  SEA PORT
# 21  SEA PORT
# 22  SEA PORT
# 23  SEA PORT
# 24  SEA PORT
# 25  SEA PORT
# 26  SEA PORT
# 27  SEA PORT
# 28  SEA PORT
# 29  SEA PORT
# 30  SEA PORT
# 31  SEA PORT
# 32  SEA PORT
# 33  SEA PORT
# 34  SEA PORT
# 35  SEA PORT
# 36  SEA PORT
# 37  SEA PORT
# 38  SEA PORT
# 39  SEA PORT
# 40  SEA PORT
# 41  SEA PORT
# 42  SEA PORT
# 43  SEA PORT
# 44  SEA PORT
# 45  SEA PORT
# 46  SEA PORT
# 47  SEA PORT
# 48  SEA PORT
# 49  SEA PORT
# 50  SEA PORT
# 51  SEA PORT
# 52  SEA PORT
# 53  SEA PORT
# 54  SEA PORT
# 55  SEA PORT
# 56  SEA PORT
# 57  SEA PORT
# 58  SEA PORT
# 59  SEA AND RIVER PORT
# 60  SEA AND RIVER PORT
# 61  SEA AND RIVER PORT
# 62  SEA AND RIVER PORT
# 63  SEA AND RIVER PORT
# 64  SEA AND RIVER PORT
# 65  SEA AND RIVER PORT
# 66  SEA AND RIVER PORT
# 67  SEA AND RIVER PORT
# 68  SEA AND RIVER PORT
# 69  SEA AND RIVER PORT
# 70  SEA AND RIVER PORT
# 71  SEA AND RIVER PORT
# 72  SEA AND RIVER PORT
# 73  SEA AND RIVER PORT

# %%
# Select indexes where territory values are equals to "Metropole"
# Assign "MAINLAND" value to entries in new column "territory"
df.loc[0:47, "territory"] = "MAINLAND"
df.loc[59:69, "territory"] = "MAINLAND"
# Out:
#                  point_of_entry_name                    office_name  \
# 0   VECTEUR MARITIME (1)              None
# 1   AJACCIO                           AJACCIO
# 2   BASTIA                            BASTIA PORT
# 3   BAYONNE                           BAYONNE
# 4   BERRE LETANG (RAFFINERIE)         PORT-DE-BOUC PORT
# 5   BORDEAUX                          BASSENS
# 6   BOULOGNE-SUR-MER                  BOULOGNE
# 7   BREST                             BREST
# 8   CAEN OUISTREHAM                   CAEN
# 9   CALAIS                            BOULOGNE
# 10  CANNES                            CANNES
# 11  CHERBOURG                         CAEN
# 12  CONCARNEAU DOUARNENEZ             BREST
# 13  DIEPPE                            ROUEN PORT
# 14  DONGES RAFFINERIE                 DONGES RAFFINERIE
# 15  DUNKERQUE                         DUNKERQUE
# 16  FECAMP                            LE HAVRE PORT
# 17  VECTEUR MARITIME (1)              None
# 18  FOS-SUR-MER (RAFFINERIE)          PORT-DE-BOUC PORT
# 19  FOS PORT-SAINT-LOUIS-DU-RHONE     FOS PORT-SAINT-LOUIS-DU-RHONE
# 20  GONFREVILLE RAFFINERIE            GONFREVILLE RAFFINERIE
# 21  HONFLEUR                          LE HAVRE PORT
# 22  LA ROCHELLE PALLICE               LA ROCHELLE PALLICE
# 23  LE HAVRE                          LE HAVRE PORT
# 24  LE HAVRE ANTIFER                  LE HAVRE ANTIFER
# 25  LA MEDE (RAFFINERIE)              PORT-DE-BOUC PORT
# 26  LAVERA (RAFFINERIE)               PORT-DE-BOUC PORT
# 27  LE TREPORT                        ROUEN PORT
# 28  LES SABLES D'OLONNES              LA ROCHE-SUR-YON
# 29  LORIENT                           LORIENT
# 30  MARSEILLE                         MARSEILLE PORT
# 31  MONACO                            MONACO
# 32  NANTES ATLANTIQUE                 NANTES ATLANTIQUE
# 33  NICE PORT                         NICE AEROPORT
# 34  PETIT COURONNE RAFFINERIE         ROUEN ENERGIES
# 35  PORT-DE-BOUC                      PORT-DE-BOUC PORT
# 36  PORT JEROME RAFFINERIE            PORT JEROME RAFFINERIE
# 37  PORT-LA-NOUVELLE                  PORT-LA-NOUVELLE
# 38  PORT VENDRES                      PORT VENDRES
# 39  PORTO-VECCHIO                     AJACCIO
# 40  VECTEUR MARITIME (1)              None
# 41  ROCHEFORT TONNAY-CHARENTE         LA ROCHELLE PALLICE
# 42  ROUEN                             ROUEN PORT
# 43  SAINT-BRIEUC LE LEGUE             SAINT-BRIEUC
# 44  SAINT-MALO                        SAINT-MALO
# 45  SAINT-NAZAIRE MONTOIR             SAINT-NAZAIRE MONTOIR
# 46  SETE                              SETE
# 47  TOULON LA SEYNE                   TOULON LA SEYNE
# 48  DOM                               None
# 49  BASSE-TERRE (GUADELOUPE)          LA POINTE JARRY
# 50  FORT-DE-FRANCE (MARTINIQUE)       FORT-DE-FRANCE PORT
# 51  KOUROU (GUYANE)                   DEGRAD DES CANNES
# 52  LA POINTE JARRY (GUADELOUPE)      LA POINTE JARRY
# 53  LE PORT (LA REUNION)              LE PORT
# 54  LE ROBERT (MARTINIQUE)            FORT-DE-FRANCE PORT
# 55  POINTE-A-PITRE (GUADELOUPE)       LA POINTE JARRY
# 56  SAINT-PIERRE (MARTINIQUE)         FORT-DE-FRANCE PORT
# 57  LONGONI (MAYOTTE)                 LONGONI PORT
# 58  DZAOUDZI (MAYOTTE)                PAMANDZI
# 59  VECTEUR FLUVIO-MARITIME           None
# 60  CHALON-SUR-SAONE                  CHALON-SUR-SAONE
# 61  GENNEVILLIERS                     GENNEVILLIERS
# 62  GRON                              AUXERRE
# 63  NOM DU  POINT D'ENTREE            NOM DU  BUREAU
# 64  VECTEUR FLUVIO-MARITIME           None
# 65  LYON PORT EDOUARD HERRIOT         LYON AEROPORT
# 66  MACON                             CHALON-SUR-SAONE
# 67  SALAISE-SUR-SANNE                 L'ISLE D'ABEAU
# 68  VALENCE                           VALENCE
# 69  VILLEFRANCHE-SUR-SAONE            LYON AEROPORT
# 70  DOM                               None
# 71  DEGRAD DES CANNES (GUYANE)        DEGRAD DES CANNES
# 72  SAINT-LAURENT DU MARONI (GUYANE)  SAINT-LAURENT DU MARONI
# 73  SAINT-GEORGES DE L'OYAPOCK        SAINT-GEORGES DE L'OYAPOCK
#
#      office_code                                   traffic          port_code  \
# 0   None          None                                      None
# 1   FR000040      MARITIME (P)  ROUTIER (R)                 FRAJA
# 2   FR000380      MARITIME (P)  ROUTIER (R)                 FRBIA
# 3   FR000390      MARITIME (P)  ROUTIER (R)                 FRBAY
# 4   FR003620      MARITIME (P)  ROUTIER (R)                 FRETB
# 5   FR000610      MARITIME (P)  ROUTIER (R)                 FRBAS FRBSE
# 6   FR000630      MARITIME (P)  ROUTIER (R)                 FRBOL
# 7   FR000690      MARITIME (P)  ROUTIER (R)                 FRBES
# 8   FR000720      MARITIME (P)  ROUTIER (R)                 FRCFR
# 9   FR000630      MARITIME (P)  ROUTIER (R)                 FRCQF
# 10  FR000800      MARITIME (P)  ROUTIER (R)                 FRCEQ
# 11  FR000720      MARITIME (P)  ROUTIER (R)                 FRCER
# 12  FR000690      MARITIME (P)  ROUTIER (R)                 FRCOC FRDRZ
# 13  FR003920      MARITIME (P)  ROUTIER (R)                 FRDPE
# 14  FR001200      MARITIME (P)  ROUTIER (R)                 FRDON
# 15  FR001260      MARITIME (P)  ROUTIER (R)                 FRDKK
# 16  FR002300      MARITIME (P)  ROUTIER (R)                 FRFEC
# 17  None          None                                      None
# 18  FR003620      MARITIME (P)  ROUTIER (R)                 FRFOS
# 19  FR003680      MARITIME (P)  ROUTIER (R)                 FRFOS
# 20  FR001560      MARITIME (P)  ROUTIER (R)                 FRGLO
# 21  FR002300      MARITIME (P)  ROUTIER (R)                 FRHON
# 22  FR002090      MARITIME (P)  ROUTIER (R)                 FRLRH
# 23  FR002300      MARITIME (P)  ROUTIER (R)                 FRLEH
# 24  FR002270      MARITIME (P)  ROUTIER (R)                 FRLEH
# 25  FR003620      MARITIME (P)  ROUTIER (R)                 FRLMD
# 26  FR003620      MARITIME (P)  ROUTIER (R)                 FRLAV
# 27  FR003920      MARITIME (P)  ROUTIER (R)                 FRLTR
# 28  FR006240      MARITIME (P)  ROUTIER (R)                 FRLSO
# 29  FR002600      MARITIME (P)  ROUTIER (R)                 FRLRT
# 30  FR002730      MARITIME (P)  ROUTIER (R)                 FRMRS
# 31  FR002860      MARITIME (P)  ROUTIER (R)                 MCMON
# 32  FR003030      MARITIME (P)  ROUTIER (R)                 FRNTE
# 33  FR003080      MARITIME (P)  ROUTIER (R)                 FRNCE
# 34  FR003500      MARITIME (P)  ROUTIER (R)                 FRPET
# 35  FR003620      MARITIME (P)  ROUTIER (R)                 FRPDB
# 36  FR003630      MARITIME (P)  ROUTIER (R)                 FRPJE
# 37  FR003650      MARITIME (P)  ROUTIER (R)                 FRNOU
# 38  FR003690      MARITIME (P)  ROUTIER (R)                 FRPOV
# 39  FR000040      MARITIME (P)  ROUTIER (R)                 FRPVO
# 40  None          None                                      None
# 41  FR002090      MARITIME (P)  ROUTIER (R)                 FRRCC FRRCO FRRCS
# 42  FR003920      MARITIME (P)  ROUTIER (R)                 FRURO
# 43  FR002310      MARITIME (P)  ROUTIER (R)                 FRSPK
# 44  FR004060      MARITIME (P)  ROUTIER (R)                 FRSML
# 45  FR004080      MARITIME (P)  ROUTIER (R)                 FRSNG FRSNP FRSNR
# 46  FR004250      MARITIME (P)  ROUTIER (R)                 FRSET
# 47  FR004430      MARITIME (P)  ROUTIER (R)                 FRTOA
# 48  None          None                                      None
# 49  FR006610      MARITIME (P)  ROUTIER (R)                 GPPTP
# 50  FR006340      MARITIME (P)  ROUTIER (R)                 MQFDF
# 51  FR006370      MARITIME (P)  ROUTIER (R)                 GFCAY
# 52  FR006610      MARITIME (P)  ROUTIER (R)                 GPPTP
# 53  FR006420      MARITIME (P)  ROUTIER (R)                 RELPT
# 54  FR006340      MARITIME (P)  ROUTIER (R)
# 55  FR006610      MARITIME (P)  ROUTIER (R)                 GPPTP
# 56  FR006340      MARITIME (P) ROUTIER (R)                  MQSPI
# 57  FR006800      MARITIME (P) ROUTIER (R)                  YTLON
# 58  FR006810      MARITIME (P)  ROUTIER (R)                 YTDZA
# 59  None          None                                      None
# 60  FR000860      MARITIME (P) FLUVIAL (C)                  FRCAO
# 61  FR003410      MARITIME (P) FLUVIAL (C)                  FRGVL
# 62  FR005500      MARITIME (P) FLUVIAL (C)                  FRGRO
# 63  Code  bureau  TRAFIC                                    Code port
# 64  None          None                                      None
# 65  FR002650      MARITIME (P) FLUVIAL (C)                  FRLIO
# 66  FR000860      MARITIME (P) FLUVIAL (C)                  FRMAC
# 67  FR002030      MARITIME (P) FLUVIAL (C)                  FRSAL
# 68  FR004550      MARITIME (P) FLUVIAL (C)                  FRVAA FRVAC FRVAF
# 69  FR002650      MARITIME (P) FLUVIAL (C)                  FRVSS
# 70  None          None                                      None
# 71  FR006370      MARITIME (P)  FLUVIAL (C) ROUTIER (R)     GFCAY
# 72  FR006390      MARITIME (P)  FLUVIAL (C) ROUTIER (R)(2)  GFSLM
# 73  FR006750      MARITIME (P) FLUVIAL (C) ROUTIER (R)      GFOYP
#
#              port_type territory
# 0   SEA PORT            MAINLAND
# 1   SEA PORT            MAINLAND
# 2   SEA PORT            MAINLAND
# 3   SEA PORT            MAINLAND
# 4   SEA PORT            MAINLAND
# 5   SEA PORT            MAINLAND
# 6   SEA PORT            MAINLAND
# 7   SEA PORT            MAINLAND
# 8   SEA PORT            MAINLAND
# 9   SEA PORT            MAINLAND
# 10  SEA PORT            MAINLAND
# 11  SEA PORT            MAINLAND
# 12  SEA PORT            MAINLAND
# 13  SEA PORT            MAINLAND
# 14  SEA PORT            MAINLAND
# 15  SEA PORT            MAINLAND
# 16  SEA PORT            MAINLAND
# 17  SEA PORT            MAINLAND
# 18  SEA PORT            MAINLAND
# 19  SEA PORT            MAINLAND
# 20  SEA PORT            MAINLAND
# 21  SEA PORT            MAINLAND
# 22  SEA PORT            MAINLAND
# 23  SEA PORT            MAINLAND
# 24  SEA PORT            MAINLAND
# 25  SEA PORT            MAINLAND
# 26  SEA PORT            MAINLAND
# 27  SEA PORT            MAINLAND
# 28  SEA PORT            MAINLAND
# 29  SEA PORT            MAINLAND
# 30  SEA PORT            MAINLAND
# 31  SEA PORT            MAINLAND
# 32  SEA PORT            MAINLAND
# 33  SEA PORT            MAINLAND
# 34  SEA PORT            MAINLAND
# 35  SEA PORT            MAINLAND
# 36  SEA PORT            MAINLAND
# 37  SEA PORT            MAINLAND
# 38  SEA PORT            MAINLAND
# 39  SEA PORT            MAINLAND
# 40  SEA PORT            MAINLAND
# 41  SEA PORT            MAINLAND
# 42  SEA PORT            MAINLAND
# 43  SEA PORT            MAINLAND
# 44  SEA PORT            MAINLAND
# 45  SEA PORT            MAINLAND
# 46  SEA PORT            MAINLAND
# 47  SEA PORT            MAINLAND
# 48  SEA PORT            NaN
# 49  SEA PORT            NaN
# 50  SEA PORT            NaN
# 51  SEA PORT            NaN
# 52  SEA PORT            NaN
# 53  SEA PORT            NaN
# 54  SEA PORT            NaN
# 55  SEA PORT            NaN
# 56  SEA PORT            NaN
# 57  SEA PORT            NaN
# 58  SEA PORT            NaN
# 59  SEA AND RIVER PORT  MAINLAND
# 60  SEA AND RIVER PORT  MAINLAND
# 61  SEA AND RIVER PORT  MAINLAND
# 62  SEA AND RIVER PORT  MAINLAND
# 63  SEA AND RIVER PORT  MAINLAND
# 64  SEA AND RIVER PORT  MAINLAND
# 65  SEA AND RIVER PORT  MAINLAND
# 66  SEA AND RIVER PORT  MAINLAND
# 67  SEA AND RIVER PORT  MAINLAND
# 68  SEA AND RIVER PORT  MAINLAND
# 69  SEA AND RIVER PORT  MAINLAND
# 70  SEA AND RIVER PORT  NaN
# 71  SEA AND RIVER PORT  NaN
# 72  SEA AND RIVER PORT  NaN
# 73  SEA AND RIVER PORT  NaN

# %%
# Select indexes where territory values are equals to "DOM"
# Assign "OVERSEAS" value to entries in column "territory"
df.loc[48:58, "territory"] = "OVERSEAS"
df.loc[70:74, "territory"] = "OVERSEAS"
# Out:
#                  point_of_entry_name                    office_name  \
# 0   VECTEUR MARITIME (1)              None
# 1   AJACCIO                           AJACCIO
# 2   BASTIA                            BASTIA PORT
# 3   BAYONNE                           BAYONNE
# 4   BERRE LETANG (RAFFINERIE)         PORT-DE-BOUC PORT
# 5   BORDEAUX                          BASSENS
# 6   BOULOGNE-SUR-MER                  BOULOGNE
# 7   BREST                             BREST
# 8   CAEN OUISTREHAM                   CAEN
# 9   CALAIS                            BOULOGNE
# 10  CANNES                            CANNES
# 11  CHERBOURG                         CAEN
# 12  CONCARNEAU DOUARNENEZ             BREST
# 13  DIEPPE                            ROUEN PORT
# 14  DONGES RAFFINERIE                 DONGES RAFFINERIE
# 15  DUNKERQUE                         DUNKERQUE
# 16  FECAMP                            LE HAVRE PORT
# 17  VECTEUR MARITIME (1)              None
# 18  FOS-SUR-MER (RAFFINERIE)          PORT-DE-BOUC PORT
# 19  FOS PORT-SAINT-LOUIS-DU-RHONE     FOS PORT-SAINT-LOUIS-DU-RHONE
# 20  GONFREVILLE RAFFINERIE            GONFREVILLE RAFFINERIE
# 21  HONFLEUR                          LE HAVRE PORT
# 22  LA ROCHELLE PALLICE               LA ROCHELLE PALLICE
# 23  LE HAVRE                          LE HAVRE PORT
# 24  LE HAVRE ANTIFER                  LE HAVRE ANTIFER
# 25  LA MEDE (RAFFINERIE)              PORT-DE-BOUC PORT
# 26  LAVERA (RAFFINERIE)               PORT-DE-BOUC PORT
# 27  LE TREPORT                        ROUEN PORT
# 28  LES SABLES D'OLONNES              LA ROCHE-SUR-YON
# 29  LORIENT                           LORIENT
# 30  MARSEILLE                         MARSEILLE PORT
# 31  MONACO                            MONACO
# 32  NANTES ATLANTIQUE                 NANTES ATLANTIQUE
# 33  NICE PORT                         NICE AEROPORT
# 34  PETIT COURONNE RAFFINERIE         ROUEN ENERGIES
# 35  PORT-DE-BOUC                      PORT-DE-BOUC PORT
# 36  PORT JEROME RAFFINERIE            PORT JEROME RAFFINERIE
# 37  PORT-LA-NOUVELLE                  PORT-LA-NOUVELLE
# 38  PORT VENDRES                      PORT VENDRES
# 39  PORTO-VECCHIO                     AJACCIO
# 40  VECTEUR MARITIME (1)              None
# 41  ROCHEFORT TONNAY-CHARENTE         LA ROCHELLE PALLICE
# 42  ROUEN                             ROUEN PORT
# 43  SAINT-BRIEUC LE LEGUE             SAINT-BRIEUC
# 44  SAINT-MALO                        SAINT-MALO
# 45  SAINT-NAZAIRE MONTOIR             SAINT-NAZAIRE MONTOIR
# 46  SETE                              SETE
# 47  TOULON LA SEYNE                   TOULON LA SEYNE
# 48  DOM                               None
# 49  BASSE-TERRE (GUADELOUPE)          LA POINTE JARRY
# 50  FORT-DE-FRANCE (MARTINIQUE)       FORT-DE-FRANCE PORT
# 51  KOUROU (GUYANE)                   DEGRAD DES CANNES
# 52  LA POINTE JARRY (GUADELOUPE)      LA POINTE JARRY
# 53  LE PORT (LA REUNION)              LE PORT
# 54  LE ROBERT (MARTINIQUE)            FORT-DE-FRANCE PORT
# 55  POINTE-A-PITRE (GUADELOUPE)       LA POINTE JARRY
# 56  SAINT-PIERRE (MARTINIQUE)         FORT-DE-FRANCE PORT
# 57  LONGONI (MAYOTTE)                 LONGONI PORT
# 58  DZAOUDZI (MAYOTTE)                PAMANDZI
# 59  VECTEUR FLUVIO-MARITIME           None
# 60  CHALON-SUR-SAONE                  CHALON-SUR-SAONE
# 61  GENNEVILLIERS                     GENNEVILLIERS
# 62  GRON                              AUXERRE
# 63  NOM DU  POINT D'ENTREE            NOM DU  BUREAU
# 64  VECTEUR FLUVIO-MARITIME           None
# 65  LYON PORT EDOUARD HERRIOT         LYON AEROPORT
# 66  MACON                             CHALON-SUR-SAONE
# 67  SALAISE-SUR-SANNE                 L'ISLE D'ABEAU
# 68  VALENCE                           VALENCE
# 69  VILLEFRANCHE-SUR-SAONE            LYON AEROPORT
# 70  DOM                               None
# 71  DEGRAD DES CANNES (GUYANE)        DEGRAD DES CANNES
# 72  SAINT-LAURENT DU MARONI (GUYANE)  SAINT-LAURENT DU MARONI
# 73  SAINT-GEORGES DE L'OYAPOCK        SAINT-GEORGES DE L'OYAPOCK
#
#      office_code                                   traffic          port_code  \
# 0   None          None                                      None
# 1   FR000040      MARITIME (P)  ROUTIER (R)                 FRAJA
# 2   FR000380      MARITIME (P)  ROUTIER (R)                 FRBIA
# 3   FR000390      MARITIME (P)  ROUTIER (R)                 FRBAY
# 4   FR003620      MARITIME (P)  ROUTIER (R)                 FRETB
# 5   FR000610      MARITIME (P)  ROUTIER (R)                 FRBAS FRBSE
# 6   FR000630      MARITIME (P)  ROUTIER (R)                 FRBOL
# 7   FR000690      MARITIME (P)  ROUTIER (R)                 FRBES
# 8   FR000720      MARITIME (P)  ROUTIER (R)                 FRCFR
# 9   FR000630      MARITIME (P)  ROUTIER (R)                 FRCQF
# 10  FR000800      MARITIME (P)  ROUTIER (R)                 FRCEQ
# 11  FR000720      MARITIME (P)  ROUTIER (R)                 FRCER
# 12  FR000690      MARITIME (P)  ROUTIER (R)                 FRCOC FRDRZ
# 13  FR003920      MARITIME (P)  ROUTIER (R)                 FRDPE
# 14  FR001200      MARITIME (P)  ROUTIER (R)                 FRDON
# 15  FR001260      MARITIME (P)  ROUTIER (R)                 FRDKK
# 16  FR002300      MARITIME (P)  ROUTIER (R)                 FRFEC
# 17  None          None                                      None
# 18  FR003620      MARITIME (P)  ROUTIER (R)                 FRFOS
# 19  FR003680      MARITIME (P)  ROUTIER (R)                 FRFOS
# 20  FR001560      MARITIME (P)  ROUTIER (R)                 FRGLO
# 21  FR002300      MARITIME (P)  ROUTIER (R)                 FRHON
# 22  FR002090      MARITIME (P)  ROUTIER (R)                 FRLRH
# 23  FR002300      MARITIME (P)  ROUTIER (R)                 FRLEH
# 24  FR002270      MARITIME (P)  ROUTIER (R)                 FRLEH
# 25  FR003620      MARITIME (P)  ROUTIER (R)                 FRLMD
# 26  FR003620      MARITIME (P)  ROUTIER (R)                 FRLAV
# 27  FR003920      MARITIME (P)  ROUTIER (R)                 FRLTR
# 28  FR006240      MARITIME (P)  ROUTIER (R)                 FRLSO
# 29  FR002600      MARITIME (P)  ROUTIER (R)                 FRLRT
# 30  FR002730      MARITIME (P)  ROUTIER (R)                 FRMRS
# 31  FR002860      MARITIME (P)  ROUTIER (R)                 MCMON
# 32  FR003030      MARITIME (P)  ROUTIER (R)                 FRNTE
# 33  FR003080      MARITIME (P)  ROUTIER (R)                 FRNCE
# 34  FR003500      MARITIME (P)  ROUTIER (R)                 FRPET
# 35  FR003620      MARITIME (P)  ROUTIER (R)                 FRPDB
# 36  FR003630      MARITIME (P)  ROUTIER (R)                 FRPJE
# 37  FR003650      MARITIME (P)  ROUTIER (R)                 FRNOU
# 38  FR003690      MARITIME (P)  ROUTIER (R)                 FRPOV
# 39  FR000040      MARITIME (P)  ROUTIER (R)                 FRPVO
# 40  None          None                                      None
# 41  FR002090      MARITIME (P)  ROUTIER (R)                 FRRCC FRRCO FRRCS
# 42  FR003920      MARITIME (P)  ROUTIER (R)                 FRURO
# 43  FR002310      MARITIME (P)  ROUTIER (R)                 FRSPK
# 44  FR004060      MARITIME (P)  ROUTIER (R)                 FRSML
# 45  FR004080      MARITIME (P)  ROUTIER (R)                 FRSNG FRSNP FRSNR
# 46  FR004250      MARITIME (P)  ROUTIER (R)                 FRSET
# 47  FR004430      MARITIME (P)  ROUTIER (R)                 FRTOA
# 48  None          None                                      None
# 49  FR006610      MARITIME (P)  ROUTIER (R)                 GPPTP
# 50  FR006340      MARITIME (P)  ROUTIER (R)                 MQFDF
# 51  FR006370      MARITIME (P)  ROUTIER (R)                 GFCAY
# 52  FR006610      MARITIME (P)  ROUTIER (R)                 GPPTP
# 53  FR006420      MARITIME (P)  ROUTIER (R)                 RELPT
# 54  FR006340      MARITIME (P)  ROUTIER (R)
# 55  FR006610      MARITIME (P)  ROUTIER (R)                 GPPTP
# 56  FR006340      MARITIME (P) ROUTIER (R)                  MQSPI
# 57  FR006800      MARITIME (P) ROUTIER (R)                  YTLON
# 58  FR006810      MARITIME (P)  ROUTIER (R)                 YTDZA
# 59  None          None                                      None
# 60  FR000860      MARITIME (P) FLUVIAL (C)                  FRCAO
# 61  FR003410      MARITIME (P) FLUVIAL (C)                  FRGVL
# 62  FR005500      MARITIME (P) FLUVIAL (C)                  FRGRO
# 63  Code  bureau  TRAFIC                                    Code port
# 64  None          None                                      None
# 65  FR002650      MARITIME (P) FLUVIAL (C)                  FRLIO
# 66  FR000860      MARITIME (P) FLUVIAL (C)                  FRMAC
# 67  FR002030      MARITIME (P) FLUVIAL (C)                  FRSAL
# 68  FR004550      MARITIME (P) FLUVIAL (C)                  FRVAA FRVAC FRVAF
# 69  FR002650      MARITIME (P) FLUVIAL (C)                  FRVSS
# 70  None          None                                      None
# 71  FR006370      MARITIME (P)  FLUVIAL (C) ROUTIER (R)     GFCAY
# 72  FR006390      MARITIME (P)  FLUVIAL (C) ROUTIER (R)(2)  GFSLM
# 73  FR006750      MARITIME (P) FLUVIAL (C) ROUTIER (R)      GFOYP
#
#              port_type territory
# 0   SEA PORT            MAINLAND
# 1   SEA PORT            MAINLAND
# 2   SEA PORT            MAINLAND
# 3   SEA PORT            MAINLAND
# 4   SEA PORT            MAINLAND
# 5   SEA PORT            MAINLAND
# 6   SEA PORT            MAINLAND
# 7   SEA PORT            MAINLAND
# 8   SEA PORT            MAINLAND
# 9   SEA PORT            MAINLAND
# 10  SEA PORT            MAINLAND
# 11  SEA PORT            MAINLAND
# 12  SEA PORT            MAINLAND
# 13  SEA PORT            MAINLAND
# 14  SEA PORT            MAINLAND
# 15  SEA PORT            MAINLAND
# 16  SEA PORT            MAINLAND
# 17  SEA PORT            MAINLAND
# 18  SEA PORT            MAINLAND
# 19  SEA PORT            MAINLAND
# 20  SEA PORT            MAINLAND
# 21  SEA PORT            MAINLAND
# 22  SEA PORT            MAINLAND
# 23  SEA PORT            MAINLAND
# 24  SEA PORT            MAINLAND
# 25  SEA PORT            MAINLAND
# 26  SEA PORT            MAINLAND
# 27  SEA PORT            MAINLAND
# 28  SEA PORT            MAINLAND
# 29  SEA PORT            MAINLAND
# 30  SEA PORT            MAINLAND
# 31  SEA PORT            MAINLAND
# 32  SEA PORT            MAINLAND
# 33  SEA PORT            MAINLAND
# 34  SEA PORT            MAINLAND
# 35  SEA PORT            MAINLAND
# 36  SEA PORT            MAINLAND
# 37  SEA PORT            MAINLAND
# 38  SEA PORT            MAINLAND
# 39  SEA PORT            MAINLAND
# 40  SEA PORT            MAINLAND
# 41  SEA PORT            MAINLAND
# 42  SEA PORT            MAINLAND
# 43  SEA PORT            MAINLAND
# 44  SEA PORT            MAINLAND
# 45  SEA PORT            MAINLAND
# 46  SEA PORT            MAINLAND
# 47  SEA PORT            MAINLAND
# 48  SEA PORT            OVERSEAS
# 49  SEA PORT            OVERSEAS
# 50  SEA PORT            OVERSEAS
# 51  SEA PORT            OVERSEAS
# 52  SEA PORT            OVERSEAS
# 53  SEA PORT            OVERSEAS
# 54  SEA PORT            OVERSEAS
# 55  SEA PORT            OVERSEAS
# 56  SEA PORT            OVERSEAS
# 57  SEA PORT            OVERSEAS
# 58  SEA PORT            OVERSEAS
# 59  SEA AND RIVER PORT  MAINLAND
# 60  SEA AND RIVER PORT  MAINLAND
# 61  SEA AND RIVER PORT  MAINLAND
# 62  SEA AND RIVER PORT  MAINLAND
# 63  SEA AND RIVER PORT  MAINLAND
# 64  SEA AND RIVER PORT  MAINLAND
# 65  SEA AND RIVER PORT  MAINLAND
# 66  SEA AND RIVER PORT  MAINLAND
# 67  SEA AND RIVER PORT  MAINLAND
# 68  SEA AND RIVER PORT  MAINLAND
# 69  SEA AND RIVER PORT  MAINLAND
# 70  SEA AND RIVER PORT  OVERSEAS
# 71  SEA AND RIVER PORT  OVERSEAS
# 72  SEA AND RIVER PORT  OVERSEAS
# 73  SEA AND RIVER PORT  OVERSEAS

# %%
# Remove all indexes containing vector and territory headers
# Reset index
df = df.drop([0, 17, 40, 48, 59, 63, 64, 70], axis=0).reset_index(drop=True)
# Out:
#                  point_of_entry_name                    office_name  \
# 0   AJACCIO                           AJACCIO
# 1   BASTIA                            BASTIA PORT
# 2   BAYONNE                           BAYONNE
# 3   BERRE LETANG (RAFFINERIE)         PORT-DE-BOUC PORT
# 4   BORDEAUX                          BASSENS
# 5   BOULOGNE-SUR-MER                  BOULOGNE
# 6   BREST                             BREST
# 7   CAEN OUISTREHAM                   CAEN
# 8   CALAIS                            BOULOGNE
# 9   CANNES                            CANNES
# 10  CHERBOURG                         CAEN
# 11  CONCARNEAU DOUARNENEZ             BREST
# 12  DIEPPE                            ROUEN PORT
# 13  DONGES RAFFINERIE                 DONGES RAFFINERIE
# 14  DUNKERQUE                         DUNKERQUE
# 15  FECAMP                            LE HAVRE PORT
# 16  FOS-SUR-MER (RAFFINERIE)          PORT-DE-BOUC PORT
# 17  FOS PORT-SAINT-LOUIS-DU-RHONE     FOS PORT-SAINT-LOUIS-DU-RHONE
# 18  GONFREVILLE RAFFINERIE            GONFREVILLE RAFFINERIE
# 19  HONFLEUR                          LE HAVRE PORT
# 20  LA ROCHELLE PALLICE               LA ROCHELLE PALLICE
# 21  LE HAVRE                          LE HAVRE PORT
# 22  LE HAVRE ANTIFER                  LE HAVRE ANTIFER
# 23  LA MEDE (RAFFINERIE)              PORT-DE-BOUC PORT
# 24  LAVERA (RAFFINERIE)               PORT-DE-BOUC PORT
# 25  LE TREPORT                        ROUEN PORT
# 26  LES SABLES D'OLONNES              LA ROCHE-SUR-YON
# 27  LORIENT                           LORIENT
# 28  MARSEILLE                         MARSEILLE PORT
# 29  MONACO                            MONACO
# 30  NANTES ATLANTIQUE                 NANTES ATLANTIQUE
# 31  NICE PORT                         NICE AEROPORT
# 32  PETIT COURONNE RAFFINERIE         ROUEN ENERGIES
# 33  PORT-DE-BOUC                      PORT-DE-BOUC PORT
# 34  PORT JEROME RAFFINERIE            PORT JEROME RAFFINERIE
# 35  PORT-LA-NOUVELLE                  PORT-LA-NOUVELLE
# 36  PORT VENDRES                      PORT VENDRES
# 37  PORTO-VECCHIO                     AJACCIO
# 38  ROCHEFORT TONNAY-CHARENTE         LA ROCHELLE PALLICE
# 39  ROUEN                             ROUEN PORT
# 40  SAINT-BRIEUC LE LEGUE             SAINT-BRIEUC
# 41  SAINT-MALO                        SAINT-MALO
# 42  SAINT-NAZAIRE MONTOIR             SAINT-NAZAIRE MONTOIR
# 43  SETE                              SETE
# 44  TOULON LA SEYNE                   TOULON LA SEYNE
# 45  BASSE-TERRE (GUADELOUPE)          LA POINTE JARRY
# 46  FORT-DE-FRANCE (MARTINIQUE)       FORT-DE-FRANCE PORT
# 47  KOUROU (GUYANE)                   DEGRAD DES CANNES
# 48  LA POINTE JARRY (GUADELOUPE)      LA POINTE JARRY
# 49  LE PORT (LA REUNION)              LE PORT
# 50  LE ROBERT (MARTINIQUE)            FORT-DE-FRANCE PORT
# 51  POINTE-A-PITRE (GUADELOUPE)       LA POINTE JARRY
# 52  SAINT-PIERRE (MARTINIQUE)         FORT-DE-FRANCE PORT
# 53  LONGONI (MAYOTTE)                 LONGONI PORT
# 54  DZAOUDZI (MAYOTTE)                PAMANDZI
# 55  CHALON-SUR-SAONE                  CHALON-SUR-SAONE
# 56  GENNEVILLIERS                     GENNEVILLIERS
# 57  GRON                              AUXERRE
# 58  LYON PORT EDOUARD HERRIOT         LYON AEROPORT
# 59  MACON                             CHALON-SUR-SAONE
# 60  SALAISE-SUR-SANNE                 L'ISLE D'ABEAU
# 61  VALENCE                           VALENCE
# 62  VILLEFRANCHE-SUR-SAONE            LYON AEROPORT
# 63  DEGRAD DES CANNES (GUYANE)        DEGRAD DES CANNES
# 64  SAINT-LAURENT DU MARONI (GUYANE)  SAINT-LAURENT DU MARONI
# 65  SAINT-GEORGES DE L'OYAPOCK        SAINT-GEORGES DE L'OYAPOCK
#
#    office_code                                   traffic          port_code  \
# 0   FR000040    MARITIME (P)  ROUTIER (R)                 FRAJA
# 1   FR000380    MARITIME (P)  ROUTIER (R)                 FRBIA
# 2   FR000390    MARITIME (P)  ROUTIER (R)                 FRBAY
# 3   FR003620    MARITIME (P)  ROUTIER (R)                 FRETB
# 4   FR000610    MARITIME (P)  ROUTIER (R)                 FRBAS FRBSE
# 5   FR000630    MARITIME (P)  ROUTIER (R)                 FRBOL
# 6   FR000690    MARITIME (P)  ROUTIER (R)                 FRBES
# 7   FR000720    MARITIME (P)  ROUTIER (R)                 FRCFR
# 8   FR000630    MARITIME (P)  ROUTIER (R)                 FRCQF
# 9   FR000800    MARITIME (P)  ROUTIER (R)                 FRCEQ
# 10  FR000720    MARITIME (P)  ROUTIER (R)                 FRCER
# 11  FR000690    MARITIME (P)  ROUTIER (R)                 FRCOC FRDRZ
# 12  FR003920    MARITIME (P)  ROUTIER (R)                 FRDPE
# 13  FR001200    MARITIME (P)  ROUTIER (R)                 FRDON
# 14  FR001260    MARITIME (P)  ROUTIER (R)                 FRDKK
# 15  FR002300    MARITIME (P)  ROUTIER (R)                 FRFEC
# 16  FR003620    MARITIME (P)  ROUTIER (R)                 FRFOS
# 17  FR003680    MARITIME (P)  ROUTIER (R)                 FRFOS
# 18  FR001560    MARITIME (P)  ROUTIER (R)                 FRGLO
# 19  FR002300    MARITIME (P)  ROUTIER (R)                 FRHON
# 20  FR002090    MARITIME (P)  ROUTIER (R)                 FRLRH
# 21  FR002300    MARITIME (P)  ROUTIER (R)                 FRLEH
# 22  FR002270    MARITIME (P)  ROUTIER (R)                 FRLEH
# 23  FR003620    MARITIME (P)  ROUTIER (R)                 FRLMD
# 24  FR003620    MARITIME (P)  ROUTIER (R)                 FRLAV
# 25  FR003920    MARITIME (P)  ROUTIER (R)                 FRLTR
# 26  FR006240    MARITIME (P)  ROUTIER (R)                 FRLSO
# 27  FR002600    MARITIME (P)  ROUTIER (R)                 FRLRT
# 28  FR002730    MARITIME (P)  ROUTIER (R)                 FRMRS
# 29  FR002860    MARITIME (P)  ROUTIER (R)                 MCMON
# 30  FR003030    MARITIME (P)  ROUTIER (R)                 FRNTE
# 31  FR003080    MARITIME (P)  ROUTIER (R)                 FRNCE
# 32  FR003500    MARITIME (P)  ROUTIER (R)                 FRPET
# 33  FR003620    MARITIME (P)  ROUTIER (R)                 FRPDB
# 34  FR003630    MARITIME (P)  ROUTIER (R)                 FRPJE
# 35  FR003650    MARITIME (P)  ROUTIER (R)                 FRNOU
# 36  FR003690    MARITIME (P)  ROUTIER (R)                 FRPOV
# 37  FR000040    MARITIME (P)  ROUTIER (R)                 FRPVO
# 38  FR002090    MARITIME (P)  ROUTIER (R)                 FRRCC FRRCO FRRCS
# 39  FR003920    MARITIME (P)  ROUTIER (R)                 FRURO
# 40  FR002310    MARITIME (P)  ROUTIER (R)                 FRSPK
# 41  FR004060    MARITIME (P)  ROUTIER (R)                 FRSML
# 42  FR004080    MARITIME (P)  ROUTIER (R)                 FRSNG FRSNP FRSNR
# 43  FR004250    MARITIME (P)  ROUTIER (R)                 FRSET
# 44  FR004430    MARITIME (P)  ROUTIER (R)                 FRTOA
# 45  FR006610    MARITIME (P)  ROUTIER (R)                 GPPTP
# 46  FR006340    MARITIME (P)  ROUTIER (R)                 MQFDF
# 47  FR006370    MARITIME (P)  ROUTIER (R)                 GFCAY
# 48  FR006610    MARITIME (P)  ROUTIER (R)                 GPPTP
# 49  FR006420    MARITIME (P)  ROUTIER (R)                 RELPT
# 50  FR006340    MARITIME (P)  ROUTIER (R)
# 51  FR006610    MARITIME (P)  ROUTIER (R)                 GPPTP
# 52  FR006340    MARITIME (P) ROUTIER (R)                  MQSPI
# 53  FR006800    MARITIME (P) ROUTIER (R)                  YTLON
# 54  FR006810    MARITIME (P)  ROUTIER (R)                 YTDZA
# 55  FR000860    MARITIME (P) FLUVIAL (C)                  FRCAO
# 56  FR003410    MARITIME (P) FLUVIAL (C)                  FRGVL
# 57  FR005500    MARITIME (P) FLUVIAL (C)                  FRGRO
# 58  FR002650    MARITIME (P) FLUVIAL (C)                  FRLIO
# 59  FR000860    MARITIME (P) FLUVIAL (C)                  FRMAC
# 60  FR002030    MARITIME (P) FLUVIAL (C)                  FRSAL
# 61  FR004550    MARITIME (P) FLUVIAL (C)                  FRVAA FRVAC FRVAF
# 62  FR002650    MARITIME (P) FLUVIAL (C)                  FRVSS
# 63  FR006370    MARITIME (P)  FLUVIAL (C) ROUTIER (R)     GFCAY
# 64  FR006390    MARITIME (P)  FLUVIAL (C) ROUTIER (R)(2)  GFSLM
# 65  FR006750    MARITIME (P) FLUVIAL (C) ROUTIER (R)      GFOYP
#
#              port_type territory
# 0   SEA PORT            MAINLAND
# 1   SEA PORT            MAINLAND
# 2   SEA PORT            MAINLAND
# 3   SEA PORT            MAINLAND
# 4   SEA PORT            MAINLAND
# 5   SEA PORT            MAINLAND
# 6   SEA PORT            MAINLAND
# 7   SEA PORT            MAINLAND
# 8   SEA PORT            MAINLAND
# 9   SEA PORT            MAINLAND
# 10  SEA PORT            MAINLAND
# 11  SEA PORT            MAINLAND
# 12  SEA PORT            MAINLAND
# 13  SEA PORT            MAINLAND
# 14  SEA PORT            MAINLAND
# 15  SEA PORT            MAINLAND
# 16  SEA PORT            MAINLAND
# 17  SEA PORT            MAINLAND
# 18  SEA PORT            MAINLAND
# 19  SEA PORT            MAINLAND
# 20  SEA PORT            MAINLAND
# 21  SEA PORT            MAINLAND
# 22  SEA PORT            MAINLAND
# 23  SEA PORT            MAINLAND
# 24  SEA PORT            MAINLAND
# 25  SEA PORT            MAINLAND
# 26  SEA PORT            MAINLAND
# 27  SEA PORT            MAINLAND
# 28  SEA PORT            MAINLAND
# 29  SEA PORT            MAINLAND
# 30  SEA PORT            MAINLAND
# 31  SEA PORT            MAINLAND
# 32  SEA PORT            MAINLAND
# 33  SEA PORT            MAINLAND
# 34  SEA PORT            MAINLAND
# 35  SEA PORT            MAINLAND
# 36  SEA PORT            MAINLAND
# 37  SEA PORT            MAINLAND
# 38  SEA PORT            MAINLAND
# 39  SEA PORT            MAINLAND
# 40  SEA PORT            MAINLAND
# 41  SEA PORT            MAINLAND
# 42  SEA PORT            MAINLAND
# 43  SEA PORT            MAINLAND
# 44  SEA PORT            MAINLAND
# 45  SEA PORT            OVERSEAS
# 46  SEA PORT            OVERSEAS
# 47  SEA PORT            OVERSEAS
# 48  SEA PORT            OVERSEAS
# 49  SEA PORT            OVERSEAS
# 50  SEA PORT            OVERSEAS
# 51  SEA PORT            OVERSEAS
# 52  SEA PORT            OVERSEAS
# 53  SEA PORT            OVERSEAS
# 54  SEA PORT            OVERSEAS
# 55  SEA AND RIVER PORT  MAINLAND
# 56  SEA AND RIVER PORT  MAINLAND
# 57  SEA AND RIVER PORT  MAINLAND
# 58  SEA AND RIVER PORT  MAINLAND
# 59  SEA AND RIVER PORT  MAINLAND
# 60  SEA AND RIVER PORT  MAINLAND
# 61  SEA AND RIVER PORT  MAINLAND
# 62  SEA AND RIVER PORT  MAINLAND
# 63  SEA AND RIVER PORT  OVERSEAS
# 64  SEA AND RIVER PORT  OVERSEAS
# 65  SEA AND RIVER PORT  OVERSEAS

# %%
# Replace all unique values in column "traffic" with their English translations
sorted(df.traffic.unique())
# Out:
# ['MARITIME (P)  FLUVIAL (C) ROUTIER (R)',
#  'MARITIME (P)  FLUVIAL (C) ROUTIER (R)(2)',
#  'MARITIME (P)  ROUTIER (R)',
#  'MARITIME (P) FLUVIAL (C)',
#  'MARITIME (P) FLUVIAL (C) ROUTIER (R)',
#  'MARITIME (P) ROUTIER (R)']

# %%
df["traffic"] = df.traffic.replace("MARITIME (P)  FLUVIAL (C) ROUTIER (R)", "SEA (P) RIVER (C) ROAD (R)") \
                          .replace("MARITIME (P) FLUVIAL (C) ROUTIER (R)", "SEA (P) RIVER (C) ROAD (R)") \
                          .replace("MARITIME (P)  FLUVIAL (C) ROUTIER (R)(2)", "SEA (P) RIVER (C) ROAD (R)(2)") \
                          .replace("MARITIME (P) FLUVIAL (C)", "SEA (P) RIVER (C)") \
                          .replace("MARITIME (P)  ROUTIER (R)", "SEA (P) ROAD (R)") \
                          .replace("MARITIME (P) ROUTIER (R)", "SEA (P) ROAD (R)")


sorted(df.traffic.unique())
# Out:
# ['SEA (P) RIVER (C)',
#  'SEA (P) RIVER (C) ROAD (R)',
#  'SEA (P) RIVER (C) ROAD (R)(2)',
#  'SEA (P) ROAD (R)']

# %% [markdown]
# ### 8. Do some basic analysis
#
# Make a quick analysis and write _an entire journalism sentence_ reporting the number of sea ports located in Mainland France that are first points of entry into the European Union as well as the percentage of the total number of ports in the data frame it represents.

# %%
# What is the total number of ports (how many records are there?)
record_count = len(df)

# Filter for only sea ports in French overseas territories
sea_ports = df[(df.port_type == "SEA PORT") & (df.territory == "OVERSEAS")]

# How many of those are there?
sea_ports_count = len(sea_ports)

# Calculate the percentage of the whole
pct_whole = (sea_ports_count / record_count) * 100

# %% [markdown]
# Formulate a journalistic sentence.

# %%
# Write out a formatted sentence using an f-string
story_sentence = f'Of the {record_count:,} French sea ports which constitute the first points of entry into the European Union, {sea_ports_count:,} ({pct_whole:0.2f}%) are sea ports that are located in French overseas territories.'

print(story_sentence)
# Out:
# Of the 66 French sea ports which constitute the first points of entry into the European Union, 10 (15.15%) are sea ports that are located in French overseas territories.

# %% [markdown]
# ### 9. Write the data to a CSV file

# %%
df.to_csv("list-of-french-points-of-entry-in-ue-ports.csv", sep=",", encoding="utf-8", index=False)

# %%
data = pd.read_csv("list-of-french-points-of-entry-in-ue-ports.csv")

data
# Out:
#                  point_of_entry_name                    office_name  \
# 0   AJACCIO                           AJACCIO
# 1   BASTIA                            BASTIA PORT
# 2   BAYONNE                           BAYONNE
# 3   BERRE LETANG (RAFFINERIE)         PORT-DE-BOUC PORT
# 4   BORDEAUX                          BASSENS
# 5   BOULOGNE-SUR-MER                  BOULOGNE
# 6   BREST                             BREST
# 7   CAEN OUISTREHAM                   CAEN
# 8   CALAIS                            BOULOGNE
# 9   CANNES                            CANNES
# 10  CHERBOURG                         CAEN
# 11  CONCARNEAU DOUARNENEZ             BREST
# 12  DIEPPE                            ROUEN PORT
# 13  DONGES RAFFINERIE                 DONGES RAFFINERIE
# 14  DUNKERQUE                         DUNKERQUE
# 15  FECAMP                            LE HAVRE PORT
# 16  FOS-SUR-MER (RAFFINERIE)          PORT-DE-BOUC PORT
# 17  FOS PORT-SAINT-LOUIS-DU-RHONE     FOS PORT-SAINT-LOUIS-DU-RHONE
# 18  GONFREVILLE RAFFINERIE            GONFREVILLE RAFFINERIE
# 19  HONFLEUR                          LE HAVRE PORT
# 20  LA ROCHELLE PALLICE               LA ROCHELLE PALLICE
# 21  LE HAVRE                          LE HAVRE PORT
# 22  LE HAVRE ANTIFER                  LE HAVRE ANTIFER
# 23  LA MEDE (RAFFINERIE)              PORT-DE-BOUC PORT
# 24  LAVERA (RAFFINERIE)               PORT-DE-BOUC PORT
# 25  LE TREPORT                        ROUEN PORT
# 26  LES SABLES D'OLONNES              LA ROCHE-SUR-YON
# 27  LORIENT                           LORIENT
# 28  MARSEILLE                         MARSEILLE PORT
# 29  MONACO                            MONACO
# 30  NANTES ATLANTIQUE                 NANTES ATLANTIQUE
# 31  NICE PORT                         NICE AEROPORT
# 32  PETIT COURONNE RAFFINERIE         ROUEN ENERGIES
# 33  PORT-DE-BOUC                      PORT-DE-BOUC PORT
# 34  PORT JEROME RAFFINERIE            PORT JEROME RAFFINERIE
# 35  PORT-LA-NOUVELLE                  PORT-LA-NOUVELLE
# 36  PORT VENDRES                      PORT VENDRES
# 37  PORTO-VECCHIO                     AJACCIO
# 38  ROCHEFORT TONNAY-CHARENTE         LA ROCHELLE PALLICE
# 39  ROUEN                             ROUEN PORT
# 40  SAINT-BRIEUC LE LEGUE             SAINT-BRIEUC
# 41  SAINT-MALO                        SAINT-MALO
# 42  SAINT-NAZAIRE MONTOIR             SAINT-NAZAIRE MONTOIR
# 43  SETE                              SETE
# 44  TOULON LA SEYNE                   TOULON LA SEYNE
# 45  BASSE-TERRE (GUADELOUPE)          LA POINTE JARRY
# 46  FORT-DE-FRANCE (MARTINIQUE)       FORT-DE-FRANCE PORT
# 47  KOUROU (GUYANE)                   DEGRAD DES CANNES
# 48  LA POINTE JARRY (GUADELOUPE)      LA POINTE JARRY
# 49  LE PORT (LA REUNION)              LE PORT
# 50  LE ROBERT (MARTINIQUE)            FORT-DE-FRANCE PORT
# 51  POINTE-A-PITRE (GUADELOUPE)       LA POINTE JARRY
# 52  SAINT-PIERRE (MARTINIQUE)         FORT-DE-FRANCE PORT
# 53  LONGONI (MAYOTTE)                 LONGONI PORT
# 54  DZAOUDZI (MAYOTTE)                PAMANDZI
# 55  CHALON-SUR-SAONE                  CHALON-SUR-SAONE
# 56  GENNEVILLIERS                     GENNEVILLIERS
# 57  GRON                              AUXERRE
# 58  LYON PORT EDOUARD HERRIOT         LYON AEROPORT
# 59  MACON                             CHALON-SUR-SAONE
# 60  SALAISE-SUR-SANNE                 L'ISLE D'ABEAU
# 61  VALENCE                           VALENCE
# 62  VILLEFRANCHE-SUR-SAONE            LYON AEROPORT
# 63  DEGRAD DES CANNES (GUYANE)        DEGRAD DES CANNES
# 64  SAINT-LAURENT DU MARONI (GUYANE)  SAINT-LAURENT DU MARONI
# 65  SAINT-GEORGES DE L'OYAPOCK        SAINT-GEORGES DE L'OYAPOCK
#
#    office_code                        traffic          port_code  \
# 0   FR000040    SEA (P) ROAD (R)               FRAJA
# 1   FR000380    SEA (P) ROAD (R)               FRBIA
# 2   FR000390    SEA (P) ROAD (R)               FRBAY
# 3   FR003620    SEA (P) ROAD (R)               FRETB
# 4   FR000610    SEA (P) ROAD (R)               FRBAS FRBSE
# 5   FR000630    SEA (P) ROAD (R)               FRBOL
# 6   FR000690    SEA (P) ROAD (R)               FRBES
# 7   FR000720    SEA (P) ROAD (R)               FRCFR
# 8   FR000630    SEA (P) ROAD (R)               FRCQF
# 9   FR000800    SEA (P) ROAD (R)               FRCEQ
# 10  FR000720    SEA (P) ROAD (R)               FRCER
# 11  FR000690    SEA (P) ROAD (R)               FRCOC FRDRZ
# 12  FR003920    SEA (P) ROAD (R)               FRDPE
# 13  FR001200    SEA (P) ROAD (R)               FRDON
# 14  FR001260    SEA (P) ROAD (R)               FRDKK
# 15  FR002300    SEA (P) ROAD (R)               FRFEC
# 16  FR003620    SEA (P) ROAD (R)               FRFOS
# 17  FR003680    SEA (P) ROAD (R)               FRFOS
# 18  FR001560    SEA (P) ROAD (R)               FRGLO
# 19  FR002300    SEA (P) ROAD (R)               FRHON
# 20  FR002090    SEA (P) ROAD (R)               FRLRH
# 21  FR002300    SEA (P) ROAD (R)               FRLEH
# 22  FR002270    SEA (P) ROAD (R)               FRLEH
# 23  FR003620    SEA (P) ROAD (R)               FRLMD
# 24  FR003620    SEA (P) ROAD (R)               FRLAV
# 25  FR003920    SEA (P) ROAD (R)               FRLTR
# 26  FR006240    SEA (P) ROAD (R)               FRLSO
# 27  FR002600    SEA (P) ROAD (R)               FRLRT
# 28  FR002730    SEA (P) ROAD (R)               FRMRS
# 29  FR002860    SEA (P) ROAD (R)               MCMON
# 30  FR003030    SEA (P) ROAD (R)               FRNTE
# 31  FR003080    SEA (P) ROAD (R)               FRNCE
# 32  FR003500    SEA (P) ROAD (R)               FRPET
# 33  FR003620    SEA (P) ROAD (R)               FRPDB
# 34  FR003630    SEA (P) ROAD (R)               FRPJE
# 35  FR003650    SEA (P) ROAD (R)               FRNOU
# 36  FR003690    SEA (P) ROAD (R)               FRPOV
# 37  FR000040    SEA (P) ROAD (R)               FRPVO
# 38  FR002090    SEA (P) ROAD (R)               FRRCC FRRCO FRRCS
# 39  FR003920    SEA (P) ROAD (R)               FRURO
# 40  FR002310    SEA (P) ROAD (R)               FRSPK
# 41  FR004060    SEA (P) ROAD (R)               FRSML
# 42  FR004080    SEA (P) ROAD (R)               FRSNG FRSNP FRSNR
# 43  FR004250    SEA (P) ROAD (R)               FRSET
# 44  FR004430    SEA (P) ROAD (R)               FRTOA
# 45  FR006610    SEA (P) ROAD (R)               GPPTP
# 46  FR006340    SEA (P) ROAD (R)               MQFDF
# 47  FR006370    SEA (P) ROAD (R)               GFCAY
# 48  FR006610    SEA (P) ROAD (R)               GPPTP
# 49  FR006420    SEA (P) ROAD (R)               RELPT
# 50  FR006340    SEA (P) ROAD (R)               NaN
# 51  FR006610    SEA (P) ROAD (R)               GPPTP
# 52  FR006340    SEA (P) ROAD (R)               MQSPI
# 53  FR006800    SEA (P) ROAD (R)               YTLON
# 54  FR006810    SEA (P) ROAD (R)               YTDZA
# 55  FR000860    SEA (P) RIVER (C)              FRCAO
# 56  FR003410    SEA (P) RIVER (C)              FRGVL
# 57  FR005500    SEA (P) RIVER (C)              FRGRO
# 58  FR002650    SEA (P) RIVER (C)              FRLIO
# 59  FR000860    SEA (P) RIVER (C)              FRMAC
# 60  FR002030    SEA (P) RIVER (C)              FRSAL
# 61  FR004550    SEA (P) RIVER (C)              FRVAA FRVAC FRVAF
# 62  FR002650    SEA (P) RIVER (C)              FRVSS
# 63  FR006370    SEA (P) RIVER (C) ROAD (R)     GFCAY
# 64  FR006390    SEA (P) RIVER (C) ROAD (R)(2)  GFSLM
# 65  FR006750    SEA (P) RIVER (C) ROAD (R)     GFOYP
#
#              port_type territory
# 0   SEA PORT            MAINLAND
# 1   SEA PORT            MAINLAND
# 2   SEA PORT            MAINLAND
# 3   SEA PORT            MAINLAND
# 4   SEA PORT            MAINLAND
# 5   SEA PORT            MAINLAND
# 6   SEA PORT            MAINLAND
# 7   SEA PORT            MAINLAND
# 8   SEA PORT            MAINLAND
# 9   SEA PORT            MAINLAND
# 10  SEA PORT            MAINLAND
# 11  SEA PORT            MAINLAND
# 12  SEA PORT            MAINLAND
# 13  SEA PORT            MAINLAND
# 14  SEA PORT            MAINLAND
# 15  SEA PORT            MAINLAND
# 16  SEA PORT            MAINLAND
# 17  SEA PORT            MAINLAND
# 18  SEA PORT            MAINLAND
# 19  SEA PORT            MAINLAND
# 20  SEA PORT            MAINLAND
# 21  SEA PORT            MAINLAND
# 22  SEA PORT            MAINLAND
# 23  SEA PORT            MAINLAND
# 24  SEA PORT            MAINLAND
# 25  SEA PORT            MAINLAND
# 26  SEA PORT            MAINLAND
# 27  SEA PORT            MAINLAND
# 28  SEA PORT            MAINLAND
# 29  SEA PORT            MAINLAND
# 30  SEA PORT            MAINLAND
# 31  SEA PORT            MAINLAND
# 32  SEA PORT            MAINLAND
# 33  SEA PORT            MAINLAND
# 34  SEA PORT            MAINLAND
# 35  SEA PORT            MAINLAND
# 36  SEA PORT            MAINLAND
# 37  SEA PORT            MAINLAND
# 38  SEA PORT            MAINLAND
# 39  SEA PORT            MAINLAND
# 40  SEA PORT            MAINLAND
# 41  SEA PORT            MAINLAND
# 42  SEA PORT            MAINLAND
# 43  SEA PORT            MAINLAND
# 44  SEA PORT            MAINLAND
# 45  SEA PORT            OVERSEAS
# 46  SEA PORT            OVERSEAS
# 47  SEA PORT            OVERSEAS
# 48  SEA PORT            OVERSEAS
# 49  SEA PORT            OVERSEAS
# 50  SEA PORT            OVERSEAS
# 51  SEA PORT            OVERSEAS
# 52  SEA PORT            OVERSEAS
# 53  SEA PORT            OVERSEAS
# 54  SEA PORT            OVERSEAS
# 55  SEA AND RIVER PORT  MAINLAND
# 56  SEA AND RIVER PORT  MAINLAND
# 57  SEA AND RIVER PORT  MAINLAND
# 58  SEA AND RIVER PORT  MAINLAND
# 59  SEA AND RIVER PORT  MAINLAND
# 60  SEA AND RIVER PORT  MAINLAND
# 61  SEA AND RIVER PORT  MAINLAND
# 62  SEA AND RIVER PORT  MAINLAND
# 63  SEA AND RIVER PORT  OVERSEAS
# 64  SEA AND RIVER PORT  OVERSEAS
# 65  SEA AND RIVER PORT  OVERSEAS
